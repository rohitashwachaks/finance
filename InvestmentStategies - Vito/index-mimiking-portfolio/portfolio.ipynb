# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import matplotlib.pyplot as plt
import math

# %matplotlib inline
plt.style.use("ggplot")

# %%
import yfinance as yf

def daily_returns(data : pd.Series) -> float:
    '''
        Function to calculate daily returns from daliy price data
    '''
    return(data - data.shift(1))/data.shift(1)

def tracking_error(benchmark : pd.Series, portfolio : pd.Series) -> float:
    '''
        Function to compute tracking error
    '''
    return (portfolio - benchmark).std()

# %% [markdown]
# # Read Portfolios and trading Strategies

# %%
# %run -i 'portfolio.py'

# %%
data = pd.read_csv("./data/portfolio_dataset.csv", low_memory=False)#, nrows= 10000)

data["datadate"] = pd.to_datetime(data["datadate"])
print("Number of unique tickers:",len(data.tic.value_counts()))
data = data[["datadate","tic","div","cshoc","prccd"]].sort_values(by= "datadate")\
                                                .rename({'cshoc':'shares',
                                                #     'prchd':'high',
                                                #     'prcld':'low',
                                                #     'prcod':'open',
                                                        'prccd':'close',}, axis = 1).\
                                                reset_index(drop=True)
data = data[data["datadate"] >= pd.to_datetime("01-01-2010")]



data["div"] = data["div"].fillna(0)
print("Dimensions: ",data.shape)
data
# Out:
# Number of unique tickers: 1230
# Dimensions:  (2331936, 5)
#           datadate    tic  div        shares     close
# 0       2010-01-04  AAMRQ  0.0  3.324560e+08     7.720
# 1       2010-01-04    MRO  0.0  7.078450e+08    32.110
# 2       2010-01-04    PCS  0.0  3.524010e+08     7.970
# 3       2010-01-04    LOW  0.0  1.472032e+09    23.160
# 4       2010-01-04  GOOGL  0.0  2.429990e+08   626.750
# ...            ...    ...  ...           ...       ...
# 2331931 2021-10-08  ZIONO  0.0  5.536000e+06    27.520
# 2331932 2021-10-08  ZIONP  0.0  2.646000e+06    25.005
# 2331933 2021-10-08   BKNG  0.0  4.106000e+07  2474.370
# 2331934 2021-10-08    TJX  0.0  1.202539e+09    64.740
# 2331935 2021-10-08   ALLE  0.0  8.969600e+07   131.450
#
# [2331936 rows x 5 columns]

# %% [markdown]
# ***

# %% [markdown]
# # S&P 500 Replicating Portfolio

# %% [markdown]
# ## Fetch S&P 500 Index Constituent Data

# %%
# # Create webdriver object
# webDriverLocation = '../../utils/chromedriver'
# driver = webdriver.Chrome(executable_path = webDriverLocation)

# # Get the website
# url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
# driver.get(url)

# def get_text(x):
#     return x.text

# %%
# xpath = '//*[@id="constituents"]/tbody/tr/td[1]'
# spy_ticker_set = set()
# for item in driver.find_elements_by_xpath(xpath=xpath):
#     spy_ticker_set.add(get_text(item))
# print(len(spy_ticker_set))
# # spy_ticker_set
# driver.close()

# %%
# with open('./data/spy_ticker.txt', 'w') as f:
#     for item in spy_ticker_set:
#         f.write("%s\n" % item)

# %% [markdown]
# ## Read S&P 500 Index Constituent Data

# %% [markdown]
# - Wikipedia Method

# %%
# spy_ticker_set = set()
# with open('./data/spy_ticker.txt') as f:
#     spy_ticker_set = f.readlines()
#     spy_ticker_set = {x.strip() for x in spy_ticker_set}
# print(len(spy_ticker_set))

# %% [markdown]
# - WRDS Method _(includes historical data)_

# %%
spy_ticker_data = pd.read_csv("./data/sp500_constituents.csv")
spy_ticker_set = set(spy_ticker_data["Symbol"])
print("Unique Indices:",len(spy_ticker_set))
spy_ticker = dict()
for year in spy_ticker_data["Year"].unique():
    spy_ticker[year] = list(spy_ticker_data[spy_ticker_data["Year"] == year]["Symbol"])
# spy_ticker
# Out:
# Unique Indices: 757

# %% [markdown]
# Fetch data from WRDS using the  list
#
# ***

# %% [markdown]
# ## Read Daily Stock data from WRDS

# %% [markdown]
# ### Desciption:
#
# - GVKEY: Company Code ?
# - IID  : Issue ID - Dividents ?
# - DATADATE: Date
# - TIC: Company Ticker
# - CUSIP: Company CUSIP Code
# - CONM : Company Name
# - CSHOC : Shares Outstanding
# - CSHTRD : Trading Volume
# - PRCCD : Price Close Daily
# - PRCHD : Price High Daily
# - PRCLD : Price Low Daily
# - PRCOD : Price Open Daily
# - TRFD  : Total Return Factor Daily
# - EXCHG : Stock Exchange Code
# - BUSDESC : S&P Business Description
# - GGROUP : GIC Groups
# - GIND : GIC Industries
# - GSECTOR : GIC Sector
# - GSUBIND : GIC Sub-Industry
#
# **Looking at stocks since 01 Jan 2010**

# %%
spy_dataframe = data[data["datadate"] >= pd.to_datetime("01-01-2010")]

# Temporay measure b/c our spy_ticker does not have 2021 data
spy_dataframe = data[data["datadate"] <= pd.to_datetime("01-01-2021")]
print("Number of unique tickers:",len(spy_dataframe.tic.value_counts()))
spy_data = spy_dataframe[["datadate","tic","div","shares","close"]].reset_index(drop=True)
print("Dimensions: ",spy_data.shape)
print(spy_data.isna().sum())
spy_data[np.isnan(spy_data.close)]
# Out:
# Number of unique tickers: 1190
# Dimensions:  (2183146, 5)
# datadate        0
# tic             0
# div             0
# shares      49497
# close         553
# dtype: int64
#           datadate    tic     div  shares  close
# 5592    2010-01-13    Z.1  0.1546     NaN    NaN
# 8973    2010-01-20  RRD.2  0.2721     NaN    NaN
# 12443   2010-01-27  5050B  0.1950     NaN    NaN
# 20504   2010-02-10  0051B  0.1250     NaN    NaN
# 20505   2010-02-10  0050B  0.0730     NaN    NaN
# ...            ...    ...     ...     ...    ...
# 2141545 2020-10-15    Z.1  0.1983     NaN    NaN
# 2142940 2020-10-16  PLP.Z  0.5671     NaN    NaN
# 2165919 2020-11-30  6525B  0.4005     NaN    NaN
# 2173465 2020-12-14  AHC.2  0.3187     NaN    NaN
# 2181659 2020-12-30   PXD.  0.7018     NaN    NaN
#
# [553 rows x 5 columns]

# %% [markdown]
# **Removing 29 Oct 2012 b/c everything is NaN. so portfolio becomes Nan**
#
# Just a couple of Nan values in close.
# Should not affect quaterly averages.

# %%
spy_data.drop(index = spy_data[spy_data.close.isna()].index, inplace=True)
print(spy_data.isna().sum())
# Out:
# datadate        0
# tic             0
# div             0
# shares      48944
# close           0
# dtype: int64

# %%
spy_data = spy_data.set_index(["datadate","tic"])
spy_data
# Out:
#                    div        shares   close
# datadate   tic
# 2010-01-04 AAMRQ   0.0  3.324560e+08    7.72
#            MRO     0.0  7.078450e+08   32.11
#            PCS     0.0  3.524010e+08    7.97
#            LOW     0.0  1.472032e+09   23.16
#            GOOGL   0.0  2.429990e+08  626.75
# ...                ...           ...     ...
# 2020-12-31 EXR     0.0  1.292350e+08  115.86
#            AON     0.0  2.286160e+08  211.27
#            BAC.PM  0.0  5.590000e+07   27.31
#            MSI     0.0  1.695230e+08  170.06
#            L       0.0  2.748730e+08   45.02
#
# [2182593 rows x 3 columns]

# %%
market_calendar_dates = sorted(list(set(map(lambda x: x[0],spy_data.index.values))))
market_calendar_dates[0:5]
# Out:
# [Timestamp('2010-01-04 00:00:00'),
#  Timestamp('2010-01-05 00:00:00'),
#  Timestamp('2010-01-06 00:00:00'),
#  Timestamp('2010-01-07 00:00:00'),
#  Timestamp('2010-01-08 00:00:00')]

# %% [markdown]
# ## Executing Portfolio

# %%
# ;
# %run -i 'portfolio.py'

# %%
spy_trading_algo = SNP500_Algo("S&P 500 Algo")
spy_portfolio = Portfolio(target="S&P 500",
                        tickerset= spy_ticker, investment= 1000000,
                        trading_algo= spy_trading_algo,
                        rebalance=4, reconstitute=12)

spy_portfolio.echo()
# Out:
# Target Index: S&P 500
# Trading Algorithm: S&P 500 Algo
# Starting Investment: 1000000
# Current Investment: 1000000

# %%
portfolio_val = pd.Series([], dtype=float)
portfolio_returns = pd.Series([], dtype=float)

for date in market_calendar_dates:
    tmpdf = spy_data.loc[date,:]
    valuation, returns =  spy_portfolio.run(date= date, price= tmpdf, tickerlist = spy_ticker[date.year])
    if (valuation, returns) == (-1,-1):
        print(portfolio_val.index[-1],date.date(), valuation, returns)
        continue
    portfolio_val[date] = valuation
    portfolio_returns[date] = returns
# Out:
# Reconstitution on: 04-Jan-2010
# 	Rebalancing on: 04-Jan-2010
# <string>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 	Rebalancing on: 01-Apr-2010
# 	Rebalancing on: 01-Jul-2010
# 	Rebalancing on: 01-Oct-2010
# Reconstitution on: 03-Jan-2011
# 	Rebalancing on: 03-Jan-2011
# 	Rebalancing on: 01-Apr-2011
# 	Rebalancing on: 01-Jul-2011
# 	Rebalancing on: 03-Oct-2011
# Reconstitution on: 03-Jan-2012
# 	Rebalancing on: 03-Jan-2012
# 	Rebalancing on: 02-Apr-2012
# 	Rebalancing on: 02-Jul-2012
# 	Rebalancing on: 01-Oct-2012
# 2012-10-26 00:00:00 2012-10-29 -1 -1
# Reconstitution on: 02-Jan-2013
# 	Rebalancing on: 02-Jan-2013
# 	Rebalancing on: 01-Apr-2013
# 	Rebalancing on: 01-Jul-2013
# 	Rebalancing on: 01-Oct-2013
# Reconstitution on: 02-Jan-2014
# 	Rebalancing on: 02-Jan-2014
# 	Rebalancing on: 01-Apr-2014
# 2014-05-23 00:00:00 2014-05-26 -1 -1
# 	Rebalancing on: 01-Jul-2014
# 2014-07-03 00:00:00 2014-07-04 -1 -1
# 	Rebalancing on: 01-Oct-2014
# 2014-11-26 00:00:00 2014-11-27 -1 -1
# Reconstitution on: 02-Jan-2015
# 	Rebalancing on: 02-Jan-2015
# 2015-01-16 00:00:00 2015-01-19 -1 -1
# 	Rebalancing on: 01-Apr-2015
# 2015-05-22 00:00:00 2015-05-25 -1 -1
# 	Rebalancing on: 01-Jul-2015
# 2015-07-02 00:00:00 2015-07-03 -1 -1
# 	Rebalancing on: 01-Oct-2015
# 2015-11-25 00:00:00 2015-11-26 -1 -1
# Reconstitution on: 04-Jan-2016
# 	Rebalancing on: 04-Jan-2016
# 2016-01-15 00:00:00 2016-01-18 -1 -1
# 	Rebalancing on: 01-Apr-2016
# 2016-05-27 00:00:00 2016-05-30 -1 -1
# 	Rebalancing on: 01-Jul-2016
# 2016-07-01 00:00:00 2016-07-04 -1 -1
# 	Rebalancing on: 03-Oct-2016
# 2016-11-23 00:00:00 2016-11-24 -1 -1
# Reconstitution on: 03-Jan-2017
# 	Rebalancing on: 03-Jan-2017
# 2017-01-13 00:00:00 2017-01-16 -1 -1
# 	Rebalancing on: 03-Apr-2017
# 	Rebalancing on: 03-Jul-2017
# 	Rebalancing on: 02-Oct-2017
# Reconstitution on: 02-Jan-2018
# 	Rebalancing on: 02-Jan-2018
# 	Rebalancing on: 02-Apr-2018
# 	Rebalancing on: 02-Jul-2018
# 	Rebalancing on: 01-Oct-2018
# Reconstitution on: 02-Jan-2019
# 	Rebalancing on: 02-Jan-2019
# 	Rebalancing on: 01-Apr-2019
# 2019-05-24 00:00:00 2019-05-27 -1 -1
# 	Rebalancing on: 01-Jul-2019
# 2019-07-03 00:00:00 2019-07-04 -1 -1
# 	Rebalancing on: 01-Oct-2019
# 2019-11-27 00:00:00 2019-11-28 -1 -1
# Reconstitution on: 02-Jan-2020
# 	Rebalancing on: 02-Jan-2020
# 2020-01-17 00:00:00 2020-01-20 -1 -1
# 	Rebalancing on: 01-Apr-2020
# 2020-05-22 00:00:00 2020-05-25 -1 -1
# 	Rebalancing on: 01-Jul-2020
# 2020-07-02 00:00:00 2020-07-03 -1 -1
# 	Rebalancing on: 01-Oct-2020
# 2020-11-25 00:00:00 2020-11-26 -1 -1

# %%
spy_portfolio.echo()
# print("Net return since start: ",spy_portfolio.net_return()*100,"%")
# Out:
# Target Index: S&P 500
# Trading Algorithm: S&P 500 Algo
# Starting Investment: 1000000
# Current Investment: 3083313.277947321
# Constituent Indices: MMM, ABT, ABBV, ABMD, ACN ...
# Constituent Weights: tic
# LKQ      28.463803
# TTWO     10.695359
# ORCL    281.640800
# BAC     810.446449
# GPS      34.946179
# dtype: float64

# %%
from scipy.stats.mstats import gmean
print("daily return: ",(gmean(portfolio_returns.fillna(1)+1)-1)*100,"%")
# Out:
# daily return:  0.04110993685435549 %

# %% [markdown]
# ## S&P Index, ETF and Mutual Fund

# %%
benchmark_data = yf.download("^GSPC SPY VFIAX", start="2010-01-01", end="2020-12-31")
benchmark_data = benchmark_data["Close"]#.loc[portfolio_returns.index]
benchmark_data.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#                    SPY       VFIAX        ^GSPC
# Date
# 2010-01-04  113.330002  104.320000  1132.989990
# 2010-01-05  113.629997  104.650002  1136.520020
# 2010-01-06  113.709999  104.750000  1137.140015
# 2010-01-07  114.190002  105.180000  1141.689941
# 2010-01-08  114.570000  105.480003  1144.979980

# %%
baseline_return = benchmark_data.apply(daily_returns).fillna(0)
baseline_return.head()
# Out:
#                  SPY     VFIAX     ^GSPC
# Date
# 2010-01-04  0.000000  0.000000  0.000000
# 2010-01-05  0.002647  0.003163  0.003116
# 2010-01-06  0.000704  0.000956  0.000546
# 2010-01-07  0.004221  0.004105  0.004001
# 2010-01-08  0.003328  0.002852  0.002882

# %% [markdown]
# ## Plot

# %%
fig, ax = plt.subplots(1,2, sharex= False, sharey=False)
fig.set_size_inches(30, 10,  forward=True)

ax[0].plot(portfolio_val)
ax[0].plot(benchmark_data["^GSPC"]*900)
ax[0].plot(benchmark_data["SPY"]*8961.3)
ax[0].plot(benchmark_data["VFIAX"]*9600)
ax[0].legend(["Portfolio Value","^GSPC","SPY","VFIAX"])
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Portfolio Net Asset Value (in million $)")
ax[0].set_title("Portfolio v/s benchmarks - Valuation")

ax[1].plot(portfolio_returns)
ax[1].plot(baseline_return["^GSPC"])
ax[1].plot(baseline_return["SPY"])
ax[1].plot(baseline_return["VFIAX"])
ax[1].legend(["Portfolio Returns","^GSPC","SPY","VFIAX"])
ax[1].set_xlabel("Time")
ax[1].set_ylabel("Portfolio Daily Returns")
ax[1].set_title("Portfolio v/s benchmarks - Returns")

fig.suptitle('S&P 500 Replicating Portfolio',fontsize=20);

# %%
tracking_error_spy = baseline_return.apply(lambda x: (tracking_error(portfolio_returns,x)))
for index, value in tracking_error_spy.iteritems():
    print("Tracking error between our portfolio and {target} is {std}%".format(target = index, std = str(round(value,5)*100)))
# Out:
# Tracking error between our portfolio and SPY is 0.268%
# Tracking error between our portfolio and VFIAX is 0.329%
# Tracking error between our portfolio and ^GSPC is 0.254%

# %%
plt.figure().set_size_inches(30, 10,  forward=True)

plt.plot(portfolio_val)
plt.plot(benchmark_data["^GSPC"]*900)
plt.plot(benchmark_data["SPY"]*8961.3)
plt.plot(benchmark_data["VFIAX"]*9600)
plt.legend(["Portfolio Value","^GSPC","SPY","VFIAX"])
plt.xlabel("Time")
plt.ylabel("Portfolio Net Asset Value (in million $)")
plt.title("S&P 500 Portfolio v/s benchmarks - Valuation")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # DJIA Replicating Portfolio

# %% [markdown]
# ## Fetch DJIA Index Constituent Data

# %%
# # Create webdriver object
# webDriverLocation = '../../utils/chromedriver'
# driver = webdriver.Chrome(executable_path = webDriverLocation)

# # Get the website
# url = "https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average"
# driver.get(url)

# def get_text(x):
#     return x.text

# %%
# xpath = '//*[@id="constituents"]/tbody/tr/td[2]/a'
# djia_ticker_set = set()
# for item in driver.find_elements_by_xpath(xpath=xpath):
#     djia_ticker_set.add(get_text(item))
# print(len(djia_ticker_set))
# driver.close()
# # djia_ticker_set

# %%
# with open('./data/djia_ticker.txt', 'w') as f:
#     for item in djia_ticker_set:
#         f.write("%s\n" % item)

# %% [markdown]
# ## Read DJIA Index Constituent Data

# %% [markdown]
# - Wikipedia Method

# %%
# djia_ticker_set = set()
# with open('./data/djia_ticker.txt') as f:
#     djia_ticker_set = f.readlines()
#     djia_ticker_set = {x.strip() for x in djia_ticker_set}
# print(len(djia_ticker_set))

# %% [markdown]
# - WRDS Method _(includes historical data)_

# %%
djia_ticker_data = pd.read_csv("./data/dj_constituents.csv")
djia_ticker_set = set(djia_ticker_data["Symbol"])
print("Unique Indices:",len(djia_ticker_data))
djia_ticker = dict()
for year in djia_ticker_data["Year"].unique():
    djia_ticker[year] = list(djia_ticker_data[djia_ticker_data["Year"] == year]["Symbol"])
djia_ticker
# Out:
# Unique Indices: 330
# {2010: ['MMM',
#   'DD',
#   'MCD',
#   'AA',
#   'XOM',
#   'MRK',
#   'AXP',
#   'GE',
#   'MSFT',
#   'T',
#   'HP',
#   'PFE',
#   'BAC',
#   'HD',
#   'PG',
#   'BA',
#   'INTC',
#   'TRV',
#   'CAT',
#   'IBM',
#   'UTX',
#   'CVX',
#   'JNJ',
#   'VZ',
#   'CSCO',
#   'JPM',
#   'WMT',
#   'KO',
#   'KFT',
#   'DIS'],
#  2011: ['MMM',
#   'DD',
#   'MCD',
#   'AA',
#   'XOM',
#   'MRK',
#   'AXP',
#   'GE',
#   'MSFT',
#   'T',
#   'HP',
#   'PFE',
#   'BAC',
#   'HD',
#   'PG',
#   'BA',
#   'INTC',
#   'TRV',
#   'CAT',
#   'IBM',
#   'UTX',
#   'CVX',
#   'JNJ',
#   'VZ',
#   'CSCO',
#   'JPM',
#   'WMT',
#   'KO',
#   'KFT',
#   'DIS'],
#  2012: ['MMM',
#   'DD',
#   'MRK',
#   'AA',
#   'XOM',
#   'MSFT',
#   'AXP',
#   'GE',
#   'PFE',
#   'T',
#   'HPQ',
#   'PG',
#   'BAC',
#   'HD',
#   'TRV',
#   'BA',
#   'INTC',
#   'UNH',
#   'CAT',
#   'IBM',
#   'UTX',
#   'CVX',
#   'JNJ',
#   'VZ',
#   'CSCO',
#   'JPM',
#   'WMT',
#   'KO',
#   'MCD',
#   'DIS'],
#  2013: ['MMM',
#   'GE',
#   'NKE',
#   'AXP',
#   'GS',
#   'PFE',
#   'T',
#   'HD',
#   'PG',
#   'BA',
#   'INTC',
#   'TRV',
#   'CAT',
#   'IBM',
#   'UNH',
#   'CVX',
#   'JNJ',
#   'UTX',
#   'CSCO',
#   'JPM',
#   'VZ',
#   'KO',
#   'MCD',
#   'V',
#   'DD',
#   'MRK',
#   'WMT',
#   'XOM',
#   'MSFT',
#   'DIS'],
#  2014: ['MMM',
#   'GE',
#   'NKE',
#   'AXP',
#   'GS',
#   'PFE',
#   'T',
#   'HD',
#   'PG',
#   'BA',
#   'INTC',
#   'TRV',
#   'CAT',
#   'IBM',
#   'UNH',
#   'CVX',
#   'JNJ',
#   'UTX',
#   'CSCO',
#   'JPM',
#   'VZ',
#   'KO',
#   'MCD',
#   'V',
#   'DD',
#   'MRK',
#   'WMT',
#   'XOM',
#   'MSFT',
#   'DIS'],
#  2015: ['MMM',
#   'GE',
#   'NKE',
#   'AXP',
#   'GS',
#   'PFE',
#   'AAPL',
#   'HD',
#   'PG',
#   'BA',
#   'INTC',
#   'TRV',
#   'CAT',
#   'IBM',
#   'UNH',
#   'CVX',
#   'JNJ',
#   'UTX',
#   'CSCO',
#   'JPM',
#   'VZ',
#   'KO',
#   'MCD',
#   'V',
#   'DD',
#   'MRK',
#   'WMT',
#   'XOM',
#   'MSFT',
#   'DIS'],
#  2016: ['MMM',
#   'GE',
#   'NKE',
#   'AXP',
#   'GS',
#   'PFE',
#   'AAPL',
#   'HD',
#   'PG',
#   'BA',
#   'INTC',
#   'TRV',
#   'CAT',
#   'IBM',
#   'UNH',
#   'CVX',
#   'JNJ',
#   'UTX',
#   'CSCO',
#   'JPM',
#   'VZ',
#   'KO',
#   'MCD',
#   'V',
#   'DD',
#   'MRK',
#   'WMT',
#   'XOM',
#   'MSFT',
#   'DIS'],
#  2017: ['MMM',
#   'GE',
#   'NKE',
#   'AXP',
#   'GS',
#   'PFE',
#   'AAPL',
#   'HD',
#   'PG',
#   'BA',
#   'INTC',
#   'TRV',
#   'CAT',
#   'IBM',
#   'UNH',
#   'CVX',
#   'JNJ',
#   'UTX',
#   'CSCO',
#   'JPM',
#   'VZ',
#   'KO',
#   'MCD',
#   'V',
#   'DD',
#   'MRK',
#   'WMT',
#   'XOM',
#   'MSFT',
#   'DIS'],
#  2018: ['MMM',
#   'GS',
#   'PFE',
#   'AXP',
#   'HD',
#   'PG',
#   'AAPL',
#   'INTC',
#   'TRV',
#   'BA',
#   'IBM',
#   'UNH',
#   'CAT',
#   'JNJ',
#   'UTX',
#   'CVX',
#   'JPM',
#   'VZ',
#   'CSCO',
#   'MCD',
#   'V',
#   'KO',
#   'MRK',
#   'WBA',
#   'DD',
#   'MSFT',
#   'WMT',
#   'XOM',
#   'NKE',
#   'DIS'],
#  2019: ['MMM',
#   'GS',
#   'PFE',
#   'AXP',
#   'HD',
#   'PG',
#   'AAPL',
#   'INTC',
#   'TRV',
#   'BA',
#   'IBM',
#   'UNH',
#   'CAT',
#   'JNJ',
#   'UTX',
#   'CVX',
#   'JPM',
#   'VZ',
#   'CSCO',
#   'MCD',
#   'V',
#   'KO',
#   'MRK',
#   'WBA',
#   'DOW',
#   'MSFT',
#   'WMT',
#   'NKE',
#   'DIS',
#   'XOM'],
#  2020: ['MMM',
#   'GS',
#   'NKE',
#   'AXP',
#   'HD',
#   'PG',
#   'AMGN',
#   'HON',
#   'CRM',
#   'AAPL',
#   'INTC',
#   'TRV',
#   'BA',
#   'IBM',
#   'UNH',
#   'CAT',
#   'JNJ',
#   'VZ',
#   'CVX',
#   'JPM',
#   'V',
#   'CSCO',
#   'MCD',
#   'WBA',
#   'KO',
#   'MRK',
#   'WMT',
#   'DOW',
#   'MSFT',
#   'DIS']}

# %% [markdown]
# Fetch data from WRDS using the  list
#
# ***

# %% [markdown]
# ## Read Daily Stock data from WRDS

# %% [markdown]
# ### Desciption:
#
# - GVKEY: Company Code ?
# - IID  : Issue ID - Dividents ?
# - DATADATE: Date
# - TIC: Company Ticker
# - CUSIP: Company CUSIP Code
# - CONM : Company Name
# - CSHOC : Shares Outstanding
# - CSHTRD : Trading Volume
# - PRCCD : Price Close Daily
# - PRCHD : Price High Daily
# - PRCLD : Price Low Daily
# - PRCOD : Price Open Daily
# - TRFD  : Total Return Factor Daily
# - EXCHG : Stock Exchange Code
# - BUSDESC : S&P Business Description
# - GGROUP : GIC Groups
# - GIND : GIC Industries
# - GSECTOR : GIC Sector
# - GSUBIND : GIC Sub-Industry
#
# **Looking at stocks since 01 Jan 2010**

# %%
djia_dataframe = data[data["tic"].apply(lambda x: (x in djia_ticker_set))].copy()
djia_dataframe = djia_dataframe[djia_dataframe["datadate"] >= pd.to_datetime("01-01-2010")]
print("Number of unique tickers:",len(djia_dataframe.tic.value_counts()))
djia_data = djia_dataframe[["datadate","tic","div","shares","close"]].reset_index(drop=True)
print("Dimensions: ",djia_data.shape)
print(djia_data.isna().sum())
djia_data[np.isnan(djia_data.close)]
# Out:
# Number of unique tickers: 39
# Dimensions:  (111530, 5)
# datadate    0
# tic         0
# div         0
# shares      9
# close       0
# dtype: int64
# Empty DataFrame
# Columns: [datadate, tic, div, shares, close]
# Index: []

# %%
djia_data = djia_data.set_index(["datadate","tic"])
djia_data
# Out:
#                  div        shares   close
# datadate   tic
# 2010-01-04 MMM   0.0  7.079580e+08   83.02
#            MRK   0.0  3.054476e+09   37.01
#            MCD   0.0  1.079187e+09   62.78
#            CRM   0.0  1.249000e+08   74.82
#            HD    0.0  1.700412e+09   28.67
# ...              ...           ...     ...
# 2021-10-08 HON   0.0  6.903990e+08  217.70
#            GS    0.0  3.397620e+08  392.81
#            WBA   0.0  8.649870e+08   47.38
#            WMT   0.0  2.788498e+09  139.66
#            MSFT  0.0  7.514891e+09  294.85
#
# [111530 rows x 3 columns]

# %%
market_calendar_dates = sorted(list(set(map(lambda x: x[0],djia_data.index.values))))
market_calendar_dates[0:5]
# Out:
# [Timestamp('2010-01-04 00:00:00'),
#  Timestamp('2010-01-05 00:00:00'),
#  Timestamp('2010-01-06 00:00:00'),
#  Timestamp('2010-01-07 00:00:00'),
#  Timestamp('2010-01-08 00:00:00')]

# %% [markdown]
# ## Executing Portfolio

# %%
# ;
# %run -i 'portfolio.py'

# %%
djia_trading_algo = DJIA_Algo("Dow Jones Algo")

djia_portfolio = Portfolio(target="DJIA",
                        tickerset = djia_ticker, investment= 1000000,
                        trading_algo= djia_trading_algo,
                        rebalance=1, reconstitute=12)

# djia_portfolio.echo()

# %%
portfolio_val = pd.Series([], dtype=float)
portfolio_returns = pd.Series([], dtype=float)

for date in market_calendar_dates:
    tmpdf = djia_data.loc[date,:]
    
    valuation, returns =  djia_portfolio.run(date= date, price= tmpdf, tickerlist = djia_ticker[date.year])
    portfolio_val[date] = valuation
    portfolio_returns[date] = returns
    # print(date.strftime("%d-%m-%Y"), valuation, returns)
# Out:
# Reconstitution on: 04-Jan-2010
# 	Rebalancing on: 04-Jan-2010
# 	Rebalancing on: 05-Jan-2010
# 	Rebalancing on: 06-Jan-2010
# 	Rebalancing on: 07-Jan-2010
# 	Rebalancing on: 08-Jan-2010
# 	Rebalancing on: 11-Jan-2010
# 	Rebalancing on: 12-Jan-2010
# 	Rebalancing on: 13-Jan-2010
# 	Rebalancing on: 14-Jan-2010
# 	Rebalancing on: 15-Jan-2010
# 	Rebalancing on: 19-Jan-2010
# 	Rebalancing on: 20-Jan-2010
# 	Rebalancing on: 21-Jan-2010
# 	Rebalancing on: 22-Jan-2010
# 	Rebalancing on: 25-Jan-2010
# 	Rebalancing on: 26-Jan-2010
# 	Rebalancing on: 27-Jan-2010
# 	Rebalancing on: 28-Jan-2010
# 	Rebalancing on: 29-Jan-2010
# 	Rebalancing on: 01-Feb-2010
# 	Rebalancing on: 02-Feb-2010
# 	Rebalancing on: 03-Feb-2010
# 	Rebalancing on: 04-Feb-2010
# 	Rebalancing on: 05-Feb-2010
# 	Rebalancing on: 08-Feb-2010
# 	Rebalancing on: 09-Feb-2010
# 	Rebalancing on: 10-Feb-2010
# 	Rebalancing on: 11-Feb-2010
# 	Rebalancing on: 12-Feb-2010
# 	Rebalancing on: 16-Feb-2010
# 	Rebalancing on: 17-Feb-2010
# 	Rebalancing on: 18-Feb-2010
# 	Rebalancing on: 19-Feb-2010
# 	Rebalancing on: 22-Feb-2010
# 	Rebalancing on: 23-Feb-2010
# 	Rebalancing on: 24-Feb-2010
# 	Rebalancing on: 25-Feb-2010
# 	Rebalancing on: 26-Feb-2010
# 	Rebalancing on: 01-Mar-2010
# 	Rebalancing on: 02-Mar-2010
# 	Rebalancing on: 03-Mar-2010
# 	Rebalancing on: 04-Mar-2010
# 	Rebalancing on: 05-Mar-2010
# 	Rebalancing on: 08-Mar-2010
# 	Rebalancing on: 09-Mar-2010
# 	Rebalancing on: 10-Mar-2010
# 	Rebalancing on: 11-Mar-2010
# 	Rebalancing on: 12-Mar-2010
# 	Rebalancing on: 15-Mar-2010
# 	Rebalancing on: 16-Mar-2010
# 	Rebalancing on: 17-Mar-2010
# 	Rebalancing on: 18-Mar-2010
# 	Rebalancing on: 19-Mar-2010
# 	Rebalancing on: 22-Mar-2010
# 	Rebalancing on: 23-Mar-2010
# 	Rebalancing on: 24-Mar-2010
# 	Rebalancing on: 25-Mar-2010
# 	Rebalancing on: 26-Mar-2010
# 	Rebalancing on: 29-Mar-2010
# 	Rebalancing on: 30-Mar-2010
# 	Rebalancing on: 31-Mar-2010
# 	Rebalancing on: 01-Apr-2010
# 	Rebalancing on: 05-Apr-2010
# 	Rebalancing on: 06-Apr-2010
# 	Rebalancing on: 07-Apr-2010
# 	Rebalancing on: 08-Apr-2010
# 	Rebalancing on: 09-Apr-2010
# 	Rebalancing on: 12-Apr-2010
# 	Rebalancing on: 13-Apr-2010
# 	Rebalancing on: 14-Apr-2010
# 	Rebalancing on: 15-Apr-2010
# 	Rebalancing on: 16-Apr-2010
# 	Rebalancing on: 19-Apr-2010
# 	Rebalancing on: 20-Apr-2010
# 	Rebalancing on: 21-Apr-2010
# 	Rebalancing on: 22-Apr-2010
# 	Rebalancing on: 23-Apr-2010
# 	Rebalancing on: 26-Apr-2010
# 	Rebalancing on: 27-Apr-2010
# 	Rebalancing on: 28-Apr-2010
# 	Rebalancing on: 29-Apr-2010
# 	Rebalancing on: 30-Apr-2010
# 	Rebalancing on: 03-May-2010
# 	Rebalancing on: 04-May-2010
# 	Rebalancing on: 05-May-2010
# 	Rebalancing on: 06-May-2010
# 	Rebalancing on: 07-May-2010
# 	Rebalancing on: 10-May-2010
# 	Rebalancing on: 11-May-2010
# 	Rebalancing on: 12-May-2010
# 	Rebalancing on: 13-May-2010
# 	Rebalancing on: 14-May-2010
# 	Rebalancing on: 17-May-2010
# 	Rebalancing on: 18-May-2010
# 	Rebalancing on: 19-May-2010
# 	Rebalancing on: 20-May-2010
# 	Rebalancing on: 21-May-2010
# 	Rebalancing on: 24-May-2010
# 	Rebalancing on: 25-May-2010
# 	Rebalancing on: 26-May-2010
# 	Rebalancing on: 27-May-2010
# 	Rebalancing on: 28-May-2010
# 	Rebalancing on: 01-Jun-2010
# 	Rebalancing on: 02-Jun-2010
# 	Rebalancing on: 03-Jun-2010
# 	Rebalancing on: 04-Jun-2010
# 	Rebalancing on: 07-Jun-2010
# 	Rebalancing on: 08-Jun-2010
# 	Rebalancing on: 09-Jun-2010
# 	Rebalancing on: 10-Jun-2010
# 	Rebalancing on: 11-Jun-2010
# 	Rebalancing on: 14-Jun-2010
# 	Rebalancing on: 15-Jun-2010
# 	Rebalancing on: 16-Jun-2010
# 	Rebalancing on: 17-Jun-2010
# 	Rebalancing on: 18-Jun-2010
# 	Rebalancing on: 21-Jun-2010
# 	Rebalancing on: 22-Jun-2010
# 	Rebalancing on: 23-Jun-2010
# 	Rebalancing on: 24-Jun-2010
# 	Rebalancing on: 25-Jun-2010
# 	Rebalancing on: 28-Jun-2010
# 	Rebalancing on: 29-Jun-2010
# 	Rebalancing on: 30-Jun-2010
# 	Rebalancing on: 01-Jul-2010
# 	Rebalancing on: 02-Jul-2010
# 	Rebalancing on: 06-Jul-2010
# 	Rebalancing on: 07-Jul-2010
# 	Rebalancing on: 08-Jul-2010
# 	Rebalancing on: 09-Jul-2010
# 	Rebalancing on: 12-Jul-2010
# 	Rebalancing on: 13-Jul-2010
# 	Rebalancing on: 14-Jul-2010
# 	Rebalancing on: 15-Jul-2010
# 	Rebalancing on: 16-Jul-2010
# 	Rebalancing on: 19-Jul-2010
# 	Rebalancing on: 20-Jul-2010
# 	Rebalancing on: 21-Jul-2010
# 	Rebalancing on: 22-Jul-2010
# 	Rebalancing on: 23-Jul-2010
# 	Rebalancing on: 26-Jul-2010
# 	Rebalancing on: 27-Jul-2010
# 	Rebalancing on: 28-Jul-2010
# 	Rebalancing on: 29-Jul-2010
# 	Rebalancing on: 30-Jul-2010
# 	Rebalancing on: 02-Aug-2010
# 	Rebalancing on: 03-Aug-2010
# 	Rebalancing on: 04-Aug-2010
# 	Rebalancing on: 05-Aug-2010
# 	Rebalancing on: 06-Aug-2010
# 	Rebalancing on: 09-Aug-2010
# 	Rebalancing on: 10-Aug-2010
# 	Rebalancing on: 11-Aug-2010
# 	Rebalancing on: 12-Aug-2010
# 	Rebalancing on: 13-Aug-2010
# 	Rebalancing on: 16-Aug-2010
# 	Rebalancing on: 17-Aug-2010
# 	Rebalancing on: 18-Aug-2010
# 	Rebalancing on: 19-Aug-2010
# 	Rebalancing on: 20-Aug-2010
# 	Rebalancing on: 23-Aug-2010
# 	Rebalancing on: 24-Aug-2010
# 	Rebalancing on: 25-Aug-2010
# 	Rebalancing on: 26-Aug-2010
# 	Rebalancing on: 27-Aug-2010
# 	Rebalancing on: 30-Aug-2010
# 	Rebalancing on: 31-Aug-2010
# 	Rebalancing on: 01-Sep-2010
# 	Rebalancing on: 02-Sep-2010
# 	Rebalancing on: 03-Sep-2010
# 	Rebalancing on: 07-Sep-2010
# 	Rebalancing on: 08-Sep-2010
# 	Rebalancing on: 09-Sep-2010
# 	Rebalancing on: 10-Sep-2010
# 	Rebalancing on: 13-Sep-2010
# 	Rebalancing on: 14-Sep-2010
# 	Rebalancing on: 15-Sep-2010
# 	Rebalancing on: 16-Sep-2010
# 	Rebalancing on: 17-Sep-2010
# 	Rebalancing on: 20-Sep-2010
# 	Rebalancing on: 21-Sep-2010
# 	Rebalancing on: 22-Sep-2010
# 	Rebalancing on: 23-Sep-2010
# 	Rebalancing on: 24-Sep-2010
# 	Rebalancing on: 27-Sep-2010
# 	Rebalancing on: 28-Sep-2010
# 	Rebalancing on: 29-Sep-2010
# 	Rebalancing on: 30-Sep-2010
# 	Rebalancing on: 01-Oct-2010
# 	Rebalancing on: 04-Oct-2010
# 	Rebalancing on: 05-Oct-2010
# 	Rebalancing on: 06-Oct-2010
# 	Rebalancing on: 07-Oct-2010
# 	Rebalancing on: 08-Oct-2010
# 	Rebalancing on: 11-Oct-2010
# 	Rebalancing on: 12-Oct-2010
# 	Rebalancing on: 13-Oct-2010
# 	Rebalancing on: 14-Oct-2010
# 	Rebalancing on: 15-Oct-2010
# 	Rebalancing on: 18-Oct-2010
# 	Rebalancing on: 19-Oct-2010
# 	Rebalancing on: 20-Oct-2010
# 	Rebalancing on: 21-Oct-2010
# 	Rebalancing on: 22-Oct-2010
# 	Rebalancing on: 25-Oct-2010
# 	Rebalancing on: 26-Oct-2010
# 	Rebalancing on: 27-Oct-2010
# 	Rebalancing on: 28-Oct-2010
# 	Rebalancing on: 29-Oct-2010
# 	Rebalancing on: 01-Nov-2010
# 	Rebalancing on: 02-Nov-2010
# 	Rebalancing on: 03-Nov-2010
# 	Rebalancing on: 04-Nov-2010
# 	Rebalancing on: 05-Nov-2010
# 	Rebalancing on: 08-Nov-2010
# 	Rebalancing on: 09-Nov-2010
# 	Rebalancing on: 10-Nov-2010
# 	Rebalancing on: 11-Nov-2010
# 	Rebalancing on: 12-Nov-2010
# 	Rebalancing on: 15-Nov-2010
# 	Rebalancing on: 16-Nov-2010
# 	Rebalancing on: 17-Nov-2010
# 	Rebalancing on: 18-Nov-2010
# 	Rebalancing on: 19-Nov-2010
# 	Rebalancing on: 22-Nov-2010
# 	Rebalancing on: 23-Nov-2010
# 	Rebalancing on: 24-Nov-2010
# 	Rebalancing on: 26-Nov-2010
# 	Rebalancing on: 29-Nov-2010
# 	Rebalancing on: 30-Nov-2010
# 	Rebalancing on: 01-Dec-2010
# 	Rebalancing on: 02-Dec-2010
# 	Rebalancing on: 03-Dec-2010
# 	Rebalancing on: 06-Dec-2010
# 	Rebalancing on: 07-Dec-2010
# 	Rebalancing on: 08-Dec-2010
# 	Rebalancing on: 09-Dec-2010
# 	Rebalancing on: 10-Dec-2010
# 	Rebalancing on: 13-Dec-2010
# 	Rebalancing on: 14-Dec-2010
# 	Rebalancing on: 15-Dec-2010
# 	Rebalancing on: 16-Dec-2010
# 	Rebalancing on: 17-Dec-2010
# 	Rebalancing on: 20-Dec-2010
# 	Rebalancing on: 21-Dec-2010
# 	Rebalancing on: 22-Dec-2010
# 	Rebalancing on: 23-Dec-2010
# 	Rebalancing on: 27-Dec-2010
# 	Rebalancing on: 28-Dec-2010
# 	Rebalancing on: 29-Dec-2010
# 	Rebalancing on: 30-Dec-2010
# 	Rebalancing on: 31-Dec-2010
# Reconstitution on: 03-Jan-2011
# 	Rebalancing on: 03-Jan-2011
# 	Rebalancing on: 04-Jan-2011
# 	Rebalancing on: 05-Jan-2011
# 	Rebalancing on: 06-Jan-2011
# 	Rebalancing on: 07-Jan-2011
# 	Rebalancing on: 10-Jan-2011
# 	Rebalancing on: 11-Jan-2011
# 	Rebalancing on: 12-Jan-2011
# 	Rebalancing on: 13-Jan-2011
# 	Rebalancing on: 14-Jan-2011
# 	Rebalancing on: 18-Jan-2011
# 	Rebalancing on: 19-Jan-2011
# 	Rebalancing on: 20-Jan-2011
# 	Rebalancing on: 21-Jan-2011
# 	Rebalancing on: 24-Jan-2011
# 	Rebalancing on: 25-Jan-2011
# 	Rebalancing on: 26-Jan-2011
# 	Rebalancing on: 27-Jan-2011
# 	Rebalancing on: 28-Jan-2011
# 	Rebalancing on: 31-Jan-2011
# 	Rebalancing on: 01-Feb-2011
# 	Rebalancing on: 02-Feb-2011
# 	Rebalancing on: 03-Feb-2011
# 	Rebalancing on: 04-Feb-2011
# 	Rebalancing on: 07-Feb-2011
# 	Rebalancing on: 08-Feb-2011
# 	Rebalancing on: 09-Feb-2011
# 	Rebalancing on: 10-Feb-2011
# 	Rebalancing on: 11-Feb-2011
# 	Rebalancing on: 14-Feb-2011
# 	Rebalancing on: 15-Feb-2011
# 	Rebalancing on: 16-Feb-2011
# 	Rebalancing on: 17-Feb-2011
# 	Rebalancing on: 18-Feb-2011
# 	Rebalancing on: 22-Feb-2011
# 	Rebalancing on: 23-Feb-2011
# 	Rebalancing on: 24-Feb-2011
# 	Rebalancing on: 25-Feb-2011
# 	Rebalancing on: 28-Feb-2011
# 	Rebalancing on: 01-Mar-2011
# 	Rebalancing on: 02-Mar-2011
# 	Rebalancing on: 03-Mar-2011
# 	Rebalancing on: 04-Mar-2011
# 	Rebalancing on: 07-Mar-2011
# 	Rebalancing on: 08-Mar-2011
# 	Rebalancing on: 09-Mar-2011
# 	Rebalancing on: 10-Mar-2011
# 	Rebalancing on: 11-Mar-2011
# 	Rebalancing on: 14-Mar-2011
# 	Rebalancing on: 15-Mar-2011
# 	Rebalancing on: 16-Mar-2011
# 	Rebalancing on: 17-Mar-2011
# 	Rebalancing on: 18-Mar-2011
# 	Rebalancing on: 21-Mar-2011
# 	Rebalancing on: 22-Mar-2011
# 	Rebalancing on: 23-Mar-2011
# 	Rebalancing on: 24-Mar-2011
# 	Rebalancing on: 25-Mar-2011
# 	Rebalancing on: 28-Mar-2011
# 	Rebalancing on: 29-Mar-2011
# 	Rebalancing on: 30-Mar-2011
# 	Rebalancing on: 31-Mar-2011
# 	Rebalancing on: 01-Apr-2011
# 	Rebalancing on: 04-Apr-2011
# 	Rebalancing on: 05-Apr-2011
# 	Rebalancing on: 06-Apr-2011
# 	Rebalancing on: 07-Apr-2011
# 	Rebalancing on: 08-Apr-2011
# 	Rebalancing on: 11-Apr-2011
# 	Rebalancing on: 12-Apr-2011
# 	Rebalancing on: 13-Apr-2011
# 	Rebalancing on: 14-Apr-2011
# 	Rebalancing on: 15-Apr-2011
# 	Rebalancing on: 18-Apr-2011
# 	Rebalancing on: 19-Apr-2011
# 	Rebalancing on: 20-Apr-2011
# 	Rebalancing on: 21-Apr-2011
# 	Rebalancing on: 25-Apr-2011
# 	Rebalancing on: 26-Apr-2011
# 	Rebalancing on: 27-Apr-2011
# 	Rebalancing on: 28-Apr-2011
# 	Rebalancing on: 29-Apr-2011
# 	Rebalancing on: 02-May-2011
# 	Rebalancing on: 03-May-2011
# 	Rebalancing on: 04-May-2011
# 	Rebalancing on: 05-May-2011
# 	Rebalancing on: 06-May-2011
# 	Rebalancing on: 09-May-2011
# 	Rebalancing on: 10-May-2011
# 	Rebalancing on: 11-May-2011
# 	Rebalancing on: 12-May-2011
# 	Rebalancing on: 13-May-2011
# 	Rebalancing on: 16-May-2011
# 	Rebalancing on: 17-May-2011
# 	Rebalancing on: 18-May-2011
# 	Rebalancing on: 19-May-2011
# 	Rebalancing on: 20-May-2011
# 	Rebalancing on: 23-May-2011
# 	Rebalancing on: 24-May-2011
# 	Rebalancing on: 25-May-2011
# 	Rebalancing on: 26-May-2011
# 	Rebalancing on: 27-May-2011
# 	Rebalancing on: 31-May-2011
# 	Rebalancing on: 01-Jun-2011
# 	Rebalancing on: 02-Jun-2011
# 	Rebalancing on: 03-Jun-2011
# 	Rebalancing on: 06-Jun-2011
# 	Rebalancing on: 07-Jun-2011
# 	Rebalancing on: 08-Jun-2011
# 	Rebalancing on: 09-Jun-2011
# 	Rebalancing on: 10-Jun-2011
# 	Rebalancing on: 13-Jun-2011
# 	Rebalancing on: 14-Jun-2011
# 	Rebalancing on: 15-Jun-2011
# 	Rebalancing on: 16-Jun-2011
# 	Rebalancing on: 17-Jun-2011
# 	Rebalancing on: 20-Jun-2011
# 	Rebalancing on: 21-Jun-2011
# 	Rebalancing on: 22-Jun-2011
# 	Rebalancing on: 23-Jun-2011
# 	Rebalancing on: 24-Jun-2011
# 	Rebalancing on: 27-Jun-2011
# 	Rebalancing on: 28-Jun-2011
# 	Rebalancing on: 29-Jun-2011
# 	Rebalancing on: 30-Jun-2011
# 	Rebalancing on: 01-Jul-2011
# 	Rebalancing on: 05-Jul-2011
# 	Rebalancing on: 06-Jul-2011
# 	Rebalancing on: 07-Jul-2011
# 	Rebalancing on: 08-Jul-2011
# 	Rebalancing on: 11-Jul-2011
# 	Rebalancing on: 12-Jul-2011
# 	Rebalancing on: 13-Jul-2011
# 	Rebalancing on: 14-Jul-2011
# 	Rebalancing on: 15-Jul-2011
# 	Rebalancing on: 18-Jul-2011
# 	Rebalancing on: 19-Jul-2011
# 	Rebalancing on: 20-Jul-2011
# 	Rebalancing on: 21-Jul-2011
# 	Rebalancing on: 22-Jul-2011
# 	Rebalancing on: 25-Jul-2011
# 	Rebalancing on: 26-Jul-2011
# 	Rebalancing on: 27-Jul-2011
# 	Rebalancing on: 28-Jul-2011
# 	Rebalancing on: 29-Jul-2011
# 	Rebalancing on: 01-Aug-2011
# 	Rebalancing on: 02-Aug-2011
# 	Rebalancing on: 03-Aug-2011
# 	Rebalancing on: 04-Aug-2011
# 	Rebalancing on: 05-Aug-2011
# 	Rebalancing on: 08-Aug-2011
# 	Rebalancing on: 09-Aug-2011
# 	Rebalancing on: 10-Aug-2011
# 	Rebalancing on: 11-Aug-2011
# 	Rebalancing on: 12-Aug-2011
# 	Rebalancing on: 15-Aug-2011
# 	Rebalancing on: 16-Aug-2011
# 	Rebalancing on: 17-Aug-2011
# 	Rebalancing on: 18-Aug-2011
# 	Rebalancing on: 19-Aug-2011
# 	Rebalancing on: 22-Aug-2011
# 	Rebalancing on: 23-Aug-2011
# 	Rebalancing on: 24-Aug-2011
# 	Rebalancing on: 25-Aug-2011
# 	Rebalancing on: 26-Aug-2011
# 	Rebalancing on: 29-Aug-2011
# 	Rebalancing on: 30-Aug-2011
# 	Rebalancing on: 31-Aug-2011
# 	Rebalancing on: 01-Sep-2011
# 	Rebalancing on: 02-Sep-2011
# 	Rebalancing on: 06-Sep-2011
# 	Rebalancing on: 07-Sep-2011
# 	Rebalancing on: 08-Sep-2011
# 	Rebalancing on: 09-Sep-2011
# 	Rebalancing on: 12-Sep-2011
# 	Rebalancing on: 13-Sep-2011
# 	Rebalancing on: 14-Sep-2011
# 	Rebalancing on: 15-Sep-2011
# 	Rebalancing on: 16-Sep-2011
# 	Rebalancing on: 19-Sep-2011
# 	Rebalancing on: 20-Sep-2011
# 	Rebalancing on: 21-Sep-2011
# 	Rebalancing on: 22-Sep-2011
# 	Rebalancing on: 23-Sep-2011
# 	Rebalancing on: 26-Sep-2011
# 	Rebalancing on: 27-Sep-2011
# 	Rebalancing on: 28-Sep-2011
# 	Rebalancing on: 29-Sep-2011
# 	Rebalancing on: 30-Sep-2011
# 	Rebalancing on: 03-Oct-2011
# 	Rebalancing on: 04-Oct-2011
# 	Rebalancing on: 05-Oct-2011
# 	Rebalancing on: 06-Oct-2011
# 	Rebalancing on: 07-Oct-2011
# 	Rebalancing on: 10-Oct-2011
# 	Rebalancing on: 11-Oct-2011
# 	Rebalancing on: 12-Oct-2011
# 	Rebalancing on: 13-Oct-2011
# 	Rebalancing on: 14-Oct-2011
# 	Rebalancing on: 17-Oct-2011
# 	Rebalancing on: 18-Oct-2011
# 	Rebalancing on: 19-Oct-2011
# 	Rebalancing on: 20-Oct-2011
# 	Rebalancing on: 21-Oct-2011
# 	Rebalancing on: 24-Oct-2011
# 	Rebalancing on: 25-Oct-2011
# 	Rebalancing on: 26-Oct-2011
# 	Rebalancing on: 27-Oct-2011
# 	Rebalancing on: 28-Oct-2011
# 	Rebalancing on: 31-Oct-2011
# 	Rebalancing on: 01-Nov-2011
# 	Rebalancing on: 02-Nov-2011
# 	Rebalancing on: 03-Nov-2011
# 	Rebalancing on: 04-Nov-2011
# 	Rebalancing on: 07-Nov-2011
# 	Rebalancing on: 08-Nov-2011
# 	Rebalancing on: 09-Nov-2011
# 	Rebalancing on: 10-Nov-2011
# 	Rebalancing on: 11-Nov-2011
# 	Rebalancing on: 14-Nov-2011
# 	Rebalancing on: 15-Nov-2011
# 	Rebalancing on: 16-Nov-2011
# 	Rebalancing on: 17-Nov-2011
# 	Rebalancing on: 18-Nov-2011
# 	Rebalancing on: 21-Nov-2011
# 	Rebalancing on: 22-Nov-2011
# 	Rebalancing on: 23-Nov-2011
# 	Rebalancing on: 25-Nov-2011
# 	Rebalancing on: 28-Nov-2011
# 	Rebalancing on: 29-Nov-2011
# 	Rebalancing on: 30-Nov-2011
# 	Rebalancing on: 01-Dec-2011
# 	Rebalancing on: 02-Dec-2011
# 	Rebalancing on: 05-Dec-2011
# 	Rebalancing on: 06-Dec-2011
# 	Rebalancing on: 07-Dec-2011
# 	Rebalancing on: 08-Dec-2011
# 	Rebalancing on: 09-Dec-2011
# 	Rebalancing on: 12-Dec-2011
# 	Rebalancing on: 13-Dec-2011
# 	Rebalancing on: 14-Dec-2011
# 	Rebalancing on: 15-Dec-2011
# 	Rebalancing on: 16-Dec-2011
# 	Rebalancing on: 19-Dec-2011
# 	Rebalancing on: 20-Dec-2011
# 	Rebalancing on: 21-Dec-2011
# 	Rebalancing on: 22-Dec-2011
# 	Rebalancing on: 23-Dec-2011
# 	Rebalancing on: 27-Dec-2011
# 	Rebalancing on: 28-Dec-2011
# 	Rebalancing on: 29-Dec-2011
# 	Rebalancing on: 30-Dec-2011
# Reconstitution on: 03-Jan-2012
# 	Rebalancing on: 03-Jan-2012
# 	Rebalancing on: 04-Jan-2012
# 	Rebalancing on: 05-Jan-2012
# 	Rebalancing on: 06-Jan-2012
# 	Rebalancing on: 09-Jan-2012
# 	Rebalancing on: 10-Jan-2012
# 	Rebalancing on: 11-Jan-2012
# 	Rebalancing on: 12-Jan-2012
# 	Rebalancing on: 13-Jan-2012
# 	Rebalancing on: 17-Jan-2012
# 	Rebalancing on: 18-Jan-2012
# 	Rebalancing on: 19-Jan-2012
# 	Rebalancing on: 20-Jan-2012
# 	Rebalancing on: 23-Jan-2012
# 	Rebalancing on: 24-Jan-2012
# 	Rebalancing on: 25-Jan-2012
# 	Rebalancing on: 26-Jan-2012
# 	Rebalancing on: 27-Jan-2012
# 	Rebalancing on: 30-Jan-2012
# 	Rebalancing on: 31-Jan-2012
# 	Rebalancing on: 01-Feb-2012
# 	Rebalancing on: 02-Feb-2012
# 	Rebalancing on: 03-Feb-2012
# 	Rebalancing on: 06-Feb-2012
# 	Rebalancing on: 07-Feb-2012
# 	Rebalancing on: 08-Feb-2012
# 	Rebalancing on: 09-Feb-2012
# 	Rebalancing on: 10-Feb-2012
# 	Rebalancing on: 13-Feb-2012
# 	Rebalancing on: 14-Feb-2012
# 	Rebalancing on: 15-Feb-2012
# 	Rebalancing on: 16-Feb-2012
# 	Rebalancing on: 17-Feb-2012
# 	Rebalancing on: 21-Feb-2012
# 	Rebalancing on: 22-Feb-2012
# 	Rebalancing on: 23-Feb-2012
# 	Rebalancing on: 24-Feb-2012
# 	Rebalancing on: 27-Feb-2012
# 	Rebalancing on: 28-Feb-2012
# 	Rebalancing on: 29-Feb-2012
# 	Rebalancing on: 01-Mar-2012
# 	Rebalancing on: 02-Mar-2012
# 	Rebalancing on: 05-Mar-2012
# 	Rebalancing on: 06-Mar-2012
# 	Rebalancing on: 07-Mar-2012
# 	Rebalancing on: 08-Mar-2012
# 	Rebalancing on: 09-Mar-2012
# 	Rebalancing on: 12-Mar-2012
# 	Rebalancing on: 13-Mar-2012
# 	Rebalancing on: 14-Mar-2012
# 	Rebalancing on: 15-Mar-2012
# 	Rebalancing on: 16-Mar-2012
# 	Rebalancing on: 19-Mar-2012
# 	Rebalancing on: 20-Mar-2012
# 	Rebalancing on: 21-Mar-2012
# 	Rebalancing on: 22-Mar-2012
# 	Rebalancing on: 23-Mar-2012
# 	Rebalancing on: 26-Mar-2012
# 	Rebalancing on: 27-Mar-2012
# 	Rebalancing on: 28-Mar-2012
# 	Rebalancing on: 29-Mar-2012
# 	Rebalancing on: 30-Mar-2012
# 	Rebalancing on: 02-Apr-2012
# 	Rebalancing on: 03-Apr-2012
# 	Rebalancing on: 04-Apr-2012
# 	Rebalancing on: 05-Apr-2012
# 	Rebalancing on: 09-Apr-2012
# 	Rebalancing on: 10-Apr-2012
# 	Rebalancing on: 11-Apr-2012
# 	Rebalancing on: 12-Apr-2012
# 	Rebalancing on: 13-Apr-2012
# 	Rebalancing on: 16-Apr-2012
# 	Rebalancing on: 17-Apr-2012
# 	Rebalancing on: 18-Apr-2012
# 	Rebalancing on: 19-Apr-2012
# 	Rebalancing on: 20-Apr-2012
# 	Rebalancing on: 23-Apr-2012
# 	Rebalancing on: 24-Apr-2012
# 	Rebalancing on: 25-Apr-2012
# 	Rebalancing on: 26-Apr-2012
# 	Rebalancing on: 27-Apr-2012
# 	Rebalancing on: 30-Apr-2012
# 	Rebalancing on: 01-May-2012
# 	Rebalancing on: 02-May-2012
# 	Rebalancing on: 03-May-2012
# 	Rebalancing on: 04-May-2012
# 	Rebalancing on: 07-May-2012
# 	Rebalancing on: 08-May-2012
# 	Rebalancing on: 09-May-2012
# 	Rebalancing on: 10-May-2012
# 	Rebalancing on: 11-May-2012
# 	Rebalancing on: 14-May-2012
# 	Rebalancing on: 15-May-2012
# 	Rebalancing on: 16-May-2012
# 	Rebalancing on: 17-May-2012
# 	Rebalancing on: 18-May-2012
# 	Rebalancing on: 21-May-2012
# 	Rebalancing on: 22-May-2012
# 	Rebalancing on: 23-May-2012
# 	Rebalancing on: 24-May-2012
# 	Rebalancing on: 25-May-2012
# 	Rebalancing on: 29-May-2012
# 	Rebalancing on: 30-May-2012
# 	Rebalancing on: 31-May-2012
# 	Rebalancing on: 01-Jun-2012
# 	Rebalancing on: 04-Jun-2012
# 	Rebalancing on: 05-Jun-2012
# 	Rebalancing on: 06-Jun-2012
# 	Rebalancing on: 07-Jun-2012
# 	Rebalancing on: 08-Jun-2012
# 	Rebalancing on: 11-Jun-2012
# 	Rebalancing on: 12-Jun-2012
# 	Rebalancing on: 13-Jun-2012
# 	Rebalancing on: 14-Jun-2012
# 	Rebalancing on: 15-Jun-2012
# 	Rebalancing on: 18-Jun-2012
# 	Rebalancing on: 19-Jun-2012
# 	Rebalancing on: 20-Jun-2012
# 	Rebalancing on: 21-Jun-2012
# 	Rebalancing on: 22-Jun-2012
# 	Rebalancing on: 25-Jun-2012
# 	Rebalancing on: 26-Jun-2012
# 	Rebalancing on: 27-Jun-2012
# 	Rebalancing on: 28-Jun-2012
# 	Rebalancing on: 29-Jun-2012
# 	Rebalancing on: 02-Jul-2012
# 	Rebalancing on: 03-Jul-2012
# 	Rebalancing on: 05-Jul-2012
# 	Rebalancing on: 06-Jul-2012
# 	Rebalancing on: 09-Jul-2012
# 	Rebalancing on: 10-Jul-2012
# 	Rebalancing on: 11-Jul-2012
# 	Rebalancing on: 12-Jul-2012
# 	Rebalancing on: 13-Jul-2012
# 	Rebalancing on: 16-Jul-2012
# 	Rebalancing on: 17-Jul-2012
# 	Rebalancing on: 18-Jul-2012
# 	Rebalancing on: 19-Jul-2012
# 	Rebalancing on: 20-Jul-2012
# 	Rebalancing on: 23-Jul-2012
# 	Rebalancing on: 24-Jul-2012
# 	Rebalancing on: 25-Jul-2012
# 	Rebalancing on: 26-Jul-2012
# 	Rebalancing on: 27-Jul-2012
# 	Rebalancing on: 30-Jul-2012
# 	Rebalancing on: 31-Jul-2012
# 	Rebalancing on: 01-Aug-2012
# 	Rebalancing on: 02-Aug-2012
# 	Rebalancing on: 03-Aug-2012
# 	Rebalancing on: 06-Aug-2012
# 	Rebalancing on: 07-Aug-2012
# 	Rebalancing on: 08-Aug-2012
# 	Rebalancing on: 09-Aug-2012
# 	Rebalancing on: 10-Aug-2012
# 	Rebalancing on: 13-Aug-2012
# 	Rebalancing on: 14-Aug-2012
# 	Rebalancing on: 15-Aug-2012
# 	Rebalancing on: 16-Aug-2012
# 	Rebalancing on: 17-Aug-2012
# 	Rebalancing on: 20-Aug-2012
# 	Rebalancing on: 21-Aug-2012
# 	Rebalancing on: 22-Aug-2012
# 	Rebalancing on: 23-Aug-2012
# 	Rebalancing on: 24-Aug-2012
# 	Rebalancing on: 27-Aug-2012
# 	Rebalancing on: 28-Aug-2012
# 	Rebalancing on: 29-Aug-2012
# 	Rebalancing on: 30-Aug-2012
# 	Rebalancing on: 31-Aug-2012
# 	Rebalancing on: 04-Sep-2012
# 	Rebalancing on: 05-Sep-2012
# 	Rebalancing on: 06-Sep-2012
# 	Rebalancing on: 07-Sep-2012
# 	Rebalancing on: 10-Sep-2012
# 	Rebalancing on: 11-Sep-2012
# 	Rebalancing on: 12-Sep-2012
# 	Rebalancing on: 13-Sep-2012
# 	Rebalancing on: 14-Sep-2012
# 	Rebalancing on: 17-Sep-2012
# 	Rebalancing on: 18-Sep-2012
# 	Rebalancing on: 19-Sep-2012
# 	Rebalancing on: 20-Sep-2012
# 	Rebalancing on: 21-Sep-2012
# 	Rebalancing on: 24-Sep-2012
# 	Rebalancing on: 25-Sep-2012
# 	Rebalancing on: 26-Sep-2012
# 	Rebalancing on: 27-Sep-2012
# 	Rebalancing on: 28-Sep-2012
# 	Rebalancing on: 01-Oct-2012
# 	Rebalancing on: 02-Oct-2012
# 	Rebalancing on: 03-Oct-2012
# 	Rebalancing on: 04-Oct-2012
# 	Rebalancing on: 05-Oct-2012
# 	Rebalancing on: 08-Oct-2012
# 	Rebalancing on: 09-Oct-2012
# 	Rebalancing on: 10-Oct-2012
# 	Rebalancing on: 11-Oct-2012
# 	Rebalancing on: 12-Oct-2012
# 	Rebalancing on: 15-Oct-2012
# 	Rebalancing on: 16-Oct-2012
# 	Rebalancing on: 17-Oct-2012
# 	Rebalancing on: 18-Oct-2012
# 	Rebalancing on: 19-Oct-2012
# 	Rebalancing on: 22-Oct-2012
# 	Rebalancing on: 23-Oct-2012
# 	Rebalancing on: 24-Oct-2012
# 	Rebalancing on: 25-Oct-2012
# 	Rebalancing on: 26-Oct-2012
# 	Rebalancing on: 31-Oct-2012
# 	Rebalancing on: 01-Nov-2012
# 	Rebalancing on: 02-Nov-2012
# 	Rebalancing on: 05-Nov-2012
# 	Rebalancing on: 06-Nov-2012
# 	Rebalancing on: 07-Nov-2012
# 	Rebalancing on: 08-Nov-2012
# 	Rebalancing on: 09-Nov-2012
# 	Rebalancing on: 12-Nov-2012
# 	Rebalancing on: 13-Nov-2012
# 	Rebalancing on: 14-Nov-2012
# 	Rebalancing on: 15-Nov-2012
# 	Rebalancing on: 16-Nov-2012
# 	Rebalancing on: 19-Nov-2012
# 	Rebalancing on: 20-Nov-2012
# 	Rebalancing on: 21-Nov-2012
# 	Rebalancing on: 23-Nov-2012
# 	Rebalancing on: 26-Nov-2012
# 	Rebalancing on: 27-Nov-2012
# 	Rebalancing on: 28-Nov-2012
# 	Rebalancing on: 29-Nov-2012
# 	Rebalancing on: 30-Nov-2012
# 	Rebalancing on: 03-Dec-2012
# 	Rebalancing on: 04-Dec-2012
# 	Rebalancing on: 05-Dec-2012
# 	Rebalancing on: 06-Dec-2012
# 	Rebalancing on: 07-Dec-2012
# 	Rebalancing on: 10-Dec-2012
# 	Rebalancing on: 11-Dec-2012
# 	Rebalancing on: 12-Dec-2012
# 	Rebalancing on: 13-Dec-2012
# 	Rebalancing on: 14-Dec-2012
# 	Rebalancing on: 17-Dec-2012
# 	Rebalancing on: 18-Dec-2012
# 	Rebalancing on: 19-Dec-2012
# 	Rebalancing on: 20-Dec-2012
# 	Rebalancing on: 21-Dec-2012
# 	Rebalancing on: 24-Dec-2012
# 	Rebalancing on: 26-Dec-2012
# 	Rebalancing on: 27-Dec-2012
# 	Rebalancing on: 28-Dec-2012
# 	Rebalancing on: 31-Dec-2012
# Reconstitution on: 02-Jan-2013
# 	Rebalancing on: 02-Jan-2013
# 	Rebalancing on: 03-Jan-2013
# 	Rebalancing on: 04-Jan-2013
# 	Rebalancing on: 07-Jan-2013
# 	Rebalancing on: 08-Jan-2013
# 	Rebalancing on: 09-Jan-2013
# 	Rebalancing on: 10-Jan-2013
# 	Rebalancing on: 11-Jan-2013
# 	Rebalancing on: 14-Jan-2013
# 	Rebalancing on: 15-Jan-2013
# 	Rebalancing on: 16-Jan-2013
# 	Rebalancing on: 17-Jan-2013
# 	Rebalancing on: 18-Jan-2013
# 	Rebalancing on: 22-Jan-2013
# 	Rebalancing on: 23-Jan-2013
# 	Rebalancing on: 24-Jan-2013
# 	Rebalancing on: 25-Jan-2013
# 	Rebalancing on: 28-Jan-2013
# 	Rebalancing on: 29-Jan-2013
# 	Rebalancing on: 30-Jan-2013
# 	Rebalancing on: 31-Jan-2013
# 	Rebalancing on: 01-Feb-2013
# 	Rebalancing on: 04-Feb-2013
# 	Rebalancing on: 05-Feb-2013
# 	Rebalancing on: 06-Feb-2013
# 	Rebalancing on: 07-Feb-2013
# 	Rebalancing on: 08-Feb-2013
# 	Rebalancing on: 11-Feb-2013
# 	Rebalancing on: 12-Feb-2013
# 	Rebalancing on: 13-Feb-2013
# 	Rebalancing on: 14-Feb-2013
# 	Rebalancing on: 15-Feb-2013
# 	Rebalancing on: 19-Feb-2013
# 	Rebalancing on: 20-Feb-2013
# 	Rebalancing on: 21-Feb-2013
# 	Rebalancing on: 22-Feb-2013
# 	Rebalancing on: 25-Feb-2013
# 	Rebalancing on: 26-Feb-2013
# 	Rebalancing on: 27-Feb-2013
# 	Rebalancing on: 28-Feb-2013
# 	Rebalancing on: 01-Mar-2013
# 	Rebalancing on: 04-Mar-2013
# 	Rebalancing on: 05-Mar-2013
# 	Rebalancing on: 06-Mar-2013
# 	Rebalancing on: 07-Mar-2013
# 	Rebalancing on: 08-Mar-2013
# 	Rebalancing on: 11-Mar-2013
# 	Rebalancing on: 12-Mar-2013
# 	Rebalancing on: 13-Mar-2013
# 	Rebalancing on: 14-Mar-2013
# 	Rebalancing on: 15-Mar-2013
# 	Rebalancing on: 18-Mar-2013
# 	Rebalancing on: 19-Mar-2013
# 	Rebalancing on: 20-Mar-2013
# 	Rebalancing on: 21-Mar-2013
# 	Rebalancing on: 22-Mar-2013
# 	Rebalancing on: 25-Mar-2013
# 	Rebalancing on: 26-Mar-2013
# 	Rebalancing on: 27-Mar-2013
# 	Rebalancing on: 28-Mar-2013
# 	Rebalancing on: 01-Apr-2013
# 	Rebalancing on: 02-Apr-2013
# 	Rebalancing on: 03-Apr-2013
# 	Rebalancing on: 04-Apr-2013
# 	Rebalancing on: 05-Apr-2013
# 	Rebalancing on: 08-Apr-2013
# 	Rebalancing on: 09-Apr-2013
# 	Rebalancing on: 10-Apr-2013
# 	Rebalancing on: 11-Apr-2013
# 	Rebalancing on: 12-Apr-2013
# 	Rebalancing on: 15-Apr-2013
# 	Rebalancing on: 16-Apr-2013
# 	Rebalancing on: 17-Apr-2013
# 	Rebalancing on: 18-Apr-2013
# 	Rebalancing on: 19-Apr-2013
# 	Rebalancing on: 22-Apr-2013
# 	Rebalancing on: 23-Apr-2013
# 	Rebalancing on: 24-Apr-2013
# 	Rebalancing on: 25-Apr-2013
# 	Rebalancing on: 26-Apr-2013
# 	Rebalancing on: 29-Apr-2013
# 	Rebalancing on: 30-Apr-2013
# 	Rebalancing on: 01-May-2013
# 	Rebalancing on: 02-May-2013
# 	Rebalancing on: 03-May-2013
# 	Rebalancing on: 06-May-2013
# 	Rebalancing on: 07-May-2013
# 	Rebalancing on: 08-May-2013
# 	Rebalancing on: 09-May-2013
# 	Rebalancing on: 10-May-2013
# 	Rebalancing on: 13-May-2013
# 	Rebalancing on: 14-May-2013
# 	Rebalancing on: 15-May-2013
# 	Rebalancing on: 16-May-2013
# 	Rebalancing on: 17-May-2013
# 	Rebalancing on: 20-May-2013
# 	Rebalancing on: 21-May-2013
# 	Rebalancing on: 22-May-2013
# 	Rebalancing on: 23-May-2013
# 	Rebalancing on: 24-May-2013
# 	Rebalancing on: 28-May-2013
# 	Rebalancing on: 29-May-2013
# 	Rebalancing on: 30-May-2013
# 	Rebalancing on: 31-May-2013
# 	Rebalancing on: 03-Jun-2013
# 	Rebalancing on: 04-Jun-2013
# 	Rebalancing on: 05-Jun-2013
# 	Rebalancing on: 06-Jun-2013
# 	Rebalancing on: 07-Jun-2013
# 	Rebalancing on: 10-Jun-2013
# 	Rebalancing on: 11-Jun-2013
# 	Rebalancing on: 12-Jun-2013
# 	Rebalancing on: 13-Jun-2013
# 	Rebalancing on: 14-Jun-2013
# 	Rebalancing on: 17-Jun-2013
# 	Rebalancing on: 18-Jun-2013
# 	Rebalancing on: 19-Jun-2013
# 	Rebalancing on: 20-Jun-2013
# 	Rebalancing on: 21-Jun-2013
# 	Rebalancing on: 24-Jun-2013
# 	Rebalancing on: 25-Jun-2013
# 	Rebalancing on: 26-Jun-2013
# 	Rebalancing on: 27-Jun-2013
# 	Rebalancing on: 28-Jun-2013
# 	Rebalancing on: 01-Jul-2013
# 	Rebalancing on: 02-Jul-2013
# 	Rebalancing on: 03-Jul-2013
# 	Rebalancing on: 05-Jul-2013
# 	Rebalancing on: 08-Jul-2013
# 	Rebalancing on: 09-Jul-2013
# 	Rebalancing on: 10-Jul-2013
# 	Rebalancing on: 11-Jul-2013
# 	Rebalancing on: 12-Jul-2013
# 	Rebalancing on: 15-Jul-2013
# 	Rebalancing on: 16-Jul-2013
# 	Rebalancing on: 17-Jul-2013
# 	Rebalancing on: 18-Jul-2013
# 	Rebalancing on: 19-Jul-2013
# 	Rebalancing on: 22-Jul-2013
# 	Rebalancing on: 23-Jul-2013
# 	Rebalancing on: 24-Jul-2013
# 	Rebalancing on: 25-Jul-2013
# 	Rebalancing on: 26-Jul-2013
# 	Rebalancing on: 29-Jul-2013
# 	Rebalancing on: 30-Jul-2013
# 	Rebalancing on: 31-Jul-2013
# 	Rebalancing on: 01-Aug-2013
# 	Rebalancing on: 02-Aug-2013
# 	Rebalancing on: 05-Aug-2013
# 	Rebalancing on: 06-Aug-2013
# 	Rebalancing on: 07-Aug-2013
# 	Rebalancing on: 08-Aug-2013
# 	Rebalancing on: 09-Aug-2013
# 	Rebalancing on: 12-Aug-2013
# 	Rebalancing on: 13-Aug-2013
# 	Rebalancing on: 14-Aug-2013
# 	Rebalancing on: 15-Aug-2013
# 	Rebalancing on: 16-Aug-2013
# 	Rebalancing on: 19-Aug-2013
# 	Rebalancing on: 20-Aug-2013
# 	Rebalancing on: 21-Aug-2013
# 	Rebalancing on: 22-Aug-2013
# 	Rebalancing on: 23-Aug-2013
# 	Rebalancing on: 26-Aug-2013
# 	Rebalancing on: 27-Aug-2013
# 	Rebalancing on: 28-Aug-2013
# 	Rebalancing on: 29-Aug-2013
# 	Rebalancing on: 30-Aug-2013
# 	Rebalancing on: 03-Sep-2013
# 	Rebalancing on: 04-Sep-2013
# 	Rebalancing on: 05-Sep-2013
# 	Rebalancing on: 06-Sep-2013
# 	Rebalancing on: 09-Sep-2013
# 	Rebalancing on: 10-Sep-2013
# 	Rebalancing on: 11-Sep-2013
# 	Rebalancing on: 12-Sep-2013
# 	Rebalancing on: 13-Sep-2013
# 	Rebalancing on: 16-Sep-2013
# 	Rebalancing on: 17-Sep-2013
# 	Rebalancing on: 18-Sep-2013
# 	Rebalancing on: 19-Sep-2013
# 	Rebalancing on: 20-Sep-2013
# 	Rebalancing on: 23-Sep-2013
# 	Rebalancing on: 24-Sep-2013
# 	Rebalancing on: 25-Sep-2013
# 	Rebalancing on: 26-Sep-2013
# 	Rebalancing on: 27-Sep-2013
# 	Rebalancing on: 30-Sep-2013
# 	Rebalancing on: 01-Oct-2013
# 	Rebalancing on: 02-Oct-2013
# 	Rebalancing on: 03-Oct-2013
# 	Rebalancing on: 04-Oct-2013
# 	Rebalancing on: 07-Oct-2013
# 	Rebalancing on: 08-Oct-2013
# 	Rebalancing on: 09-Oct-2013
# 	Rebalancing on: 10-Oct-2013
# 	Rebalancing on: 11-Oct-2013
# 	Rebalancing on: 14-Oct-2013
# 	Rebalancing on: 15-Oct-2013
# 	Rebalancing on: 16-Oct-2013
# 	Rebalancing on: 17-Oct-2013
# 	Rebalancing on: 18-Oct-2013
# 	Rebalancing on: 21-Oct-2013
# 	Rebalancing on: 22-Oct-2013
# 	Rebalancing on: 23-Oct-2013
# 	Rebalancing on: 24-Oct-2013
# 	Rebalancing on: 25-Oct-2013
# 	Rebalancing on: 28-Oct-2013
# 	Rebalancing on: 29-Oct-2013
# 	Rebalancing on: 30-Oct-2013
# 	Rebalancing on: 31-Oct-2013
# 	Rebalancing on: 01-Nov-2013
# 	Rebalancing on: 04-Nov-2013
# 	Rebalancing on: 05-Nov-2013
# 	Rebalancing on: 06-Nov-2013
# 	Rebalancing on: 07-Nov-2013
# 	Rebalancing on: 08-Nov-2013
# 	Rebalancing on: 11-Nov-2013
# 	Rebalancing on: 12-Nov-2013
# 	Rebalancing on: 13-Nov-2013
# 	Rebalancing on: 14-Nov-2013
# 	Rebalancing on: 15-Nov-2013
# 	Rebalancing on: 18-Nov-2013
# 	Rebalancing on: 19-Nov-2013
# 	Rebalancing on: 20-Nov-2013
# 	Rebalancing on: 21-Nov-2013
# 	Rebalancing on: 22-Nov-2013
# 	Rebalancing on: 25-Nov-2013
# 	Rebalancing on: 26-Nov-2013
# 	Rebalancing on: 27-Nov-2013
# 	Rebalancing on: 29-Nov-2013
# 	Rebalancing on: 02-Dec-2013
# 	Rebalancing on: 03-Dec-2013
# 	Rebalancing on: 04-Dec-2013
# 	Rebalancing on: 05-Dec-2013
# 	Rebalancing on: 06-Dec-2013
# 	Rebalancing on: 09-Dec-2013
# 	Rebalancing on: 10-Dec-2013
# 	Rebalancing on: 11-Dec-2013
# 	Rebalancing on: 12-Dec-2013
# 	Rebalancing on: 13-Dec-2013
# 	Rebalancing on: 16-Dec-2013
# 	Rebalancing on: 17-Dec-2013
# 	Rebalancing on: 18-Dec-2013
# 	Rebalancing on: 19-Dec-2013
# 	Rebalancing on: 20-Dec-2013
# 	Rebalancing on: 23-Dec-2013
# 	Rebalancing on: 24-Dec-2013
# 	Rebalancing on: 26-Dec-2013
# 	Rebalancing on: 27-Dec-2013
# 	Rebalancing on: 30-Dec-2013
# 	Rebalancing on: 31-Dec-2013
# Reconstitution on: 02-Jan-2014
# 	Rebalancing on: 02-Jan-2014
# 	Rebalancing on: 03-Jan-2014
# 	Rebalancing on: 06-Jan-2014
# 	Rebalancing on: 07-Jan-2014
# 	Rebalancing on: 08-Jan-2014
# 	Rebalancing on: 09-Jan-2014
# 	Rebalancing on: 10-Jan-2014
# 	Rebalancing on: 13-Jan-2014
# 	Rebalancing on: 14-Jan-2014
# 	Rebalancing on: 15-Jan-2014
# 	Rebalancing on: 16-Jan-2014
# 	Rebalancing on: 17-Jan-2014
# 	Rebalancing on: 21-Jan-2014
# 	Rebalancing on: 22-Jan-2014
# 	Rebalancing on: 23-Jan-2014
# 	Rebalancing on: 24-Jan-2014
# 	Rebalancing on: 27-Jan-2014
# 	Rebalancing on: 28-Jan-2014
# 	Rebalancing on: 29-Jan-2014
# 	Rebalancing on: 30-Jan-2014
# 	Rebalancing on: 31-Jan-2014
# 	Rebalancing on: 03-Feb-2014
# 	Rebalancing on: 04-Feb-2014
# 	Rebalancing on: 05-Feb-2014
# 	Rebalancing on: 06-Feb-2014
# 	Rebalancing on: 07-Feb-2014
# 	Rebalancing on: 10-Feb-2014
# 	Rebalancing on: 11-Feb-2014
# 	Rebalancing on: 12-Feb-2014
# 	Rebalancing on: 13-Feb-2014
# 	Rebalancing on: 14-Feb-2014
# 	Rebalancing on: 18-Feb-2014
# 	Rebalancing on: 19-Feb-2014
# 	Rebalancing on: 20-Feb-2014
# 	Rebalancing on: 21-Feb-2014
# 	Rebalancing on: 24-Feb-2014
# 	Rebalancing on: 25-Feb-2014
# 	Rebalancing on: 26-Feb-2014
# 	Rebalancing on: 27-Feb-2014
# 	Rebalancing on: 28-Feb-2014
# 	Rebalancing on: 03-Mar-2014
# 	Rebalancing on: 04-Mar-2014
# 	Rebalancing on: 05-Mar-2014
# 	Rebalancing on: 06-Mar-2014
# 	Rebalancing on: 07-Mar-2014
# 	Rebalancing on: 10-Mar-2014
# 	Rebalancing on: 11-Mar-2014
# 	Rebalancing on: 12-Mar-2014
# 	Rebalancing on: 13-Mar-2014
# 	Rebalancing on: 14-Mar-2014
# 	Rebalancing on: 17-Mar-2014
# 	Rebalancing on: 18-Mar-2014
# 	Rebalancing on: 19-Mar-2014
# 	Rebalancing on: 20-Mar-2014
# 	Rebalancing on: 21-Mar-2014
# 	Rebalancing on: 24-Mar-2014
# 	Rebalancing on: 25-Mar-2014
# 	Rebalancing on: 26-Mar-2014
# 	Rebalancing on: 27-Mar-2014
# 	Rebalancing on: 28-Mar-2014
# 	Rebalancing on: 31-Mar-2014
# 	Rebalancing on: 01-Apr-2014
# 	Rebalancing on: 02-Apr-2014
# 	Rebalancing on: 03-Apr-2014
# 	Rebalancing on: 04-Apr-2014
# 	Rebalancing on: 07-Apr-2014
# 	Rebalancing on: 08-Apr-2014
# 	Rebalancing on: 09-Apr-2014
# 	Rebalancing on: 10-Apr-2014
# 	Rebalancing on: 11-Apr-2014
# 	Rebalancing on: 14-Apr-2014
# 	Rebalancing on: 15-Apr-2014
# 	Rebalancing on: 16-Apr-2014
# 	Rebalancing on: 17-Apr-2014
# 	Rebalancing on: 21-Apr-2014
# 	Rebalancing on: 22-Apr-2014
# 	Rebalancing on: 23-Apr-2014
# 	Rebalancing on: 24-Apr-2014
# 	Rebalancing on: 25-Apr-2014
# 	Rebalancing on: 28-Apr-2014
# 	Rebalancing on: 29-Apr-2014
# 	Rebalancing on: 30-Apr-2014
# 	Rebalancing on: 01-May-2014
# 	Rebalancing on: 02-May-2014
# 	Rebalancing on: 05-May-2014
# 	Rebalancing on: 06-May-2014
# 	Rebalancing on: 07-May-2014
# 	Rebalancing on: 08-May-2014
# 	Rebalancing on: 09-May-2014
# 	Rebalancing on: 12-May-2014
# 	Rebalancing on: 13-May-2014
# 	Rebalancing on: 14-May-2014
# 	Rebalancing on: 15-May-2014
# 	Rebalancing on: 16-May-2014
# 	Rebalancing on: 19-May-2014
# 	Rebalancing on: 20-May-2014
# 	Rebalancing on: 21-May-2014
# 	Rebalancing on: 22-May-2014
# 	Rebalancing on: 23-May-2014
# 	Rebalancing on: 27-May-2014
# 	Rebalancing on: 28-May-2014
# 	Rebalancing on: 29-May-2014
# 	Rebalancing on: 30-May-2014
# 	Rebalancing on: 02-Jun-2014
# 	Rebalancing on: 03-Jun-2014
# 	Rebalancing on: 04-Jun-2014
# 	Rebalancing on: 05-Jun-2014
# 	Rebalancing on: 06-Jun-2014
# 	Rebalancing on: 09-Jun-2014
# 	Rebalancing on: 10-Jun-2014
# 	Rebalancing on: 11-Jun-2014
# 	Rebalancing on: 12-Jun-2014
# 	Rebalancing on: 13-Jun-2014
# 	Rebalancing on: 16-Jun-2014
# 	Rebalancing on: 17-Jun-2014
# 	Rebalancing on: 18-Jun-2014
# 	Rebalancing on: 19-Jun-2014
# 	Rebalancing on: 20-Jun-2014
# 	Rebalancing on: 23-Jun-2014
# 	Rebalancing on: 24-Jun-2014
# 	Rebalancing on: 25-Jun-2014
# 	Rebalancing on: 26-Jun-2014
# 	Rebalancing on: 27-Jun-2014
# 	Rebalancing on: 30-Jun-2014
# 	Rebalancing on: 01-Jul-2014
# 	Rebalancing on: 02-Jul-2014
# 	Rebalancing on: 03-Jul-2014
# 	Rebalancing on: 07-Jul-2014
# 	Rebalancing on: 08-Jul-2014
# 	Rebalancing on: 09-Jul-2014
# 	Rebalancing on: 10-Jul-2014
# 	Rebalancing on: 11-Jul-2014
# 	Rebalancing on: 14-Jul-2014
# 	Rebalancing on: 15-Jul-2014
# 	Rebalancing on: 16-Jul-2014
# 	Rebalancing on: 17-Jul-2014
# 	Rebalancing on: 18-Jul-2014
# 	Rebalancing on: 21-Jul-2014
# 	Rebalancing on: 22-Jul-2014
# 	Rebalancing on: 23-Jul-2014
# 	Rebalancing on: 24-Jul-2014
# 	Rebalancing on: 25-Jul-2014
# 	Rebalancing on: 28-Jul-2014
# 	Rebalancing on: 29-Jul-2014
# 	Rebalancing on: 30-Jul-2014
# 	Rebalancing on: 31-Jul-2014
# 	Rebalancing on: 01-Aug-2014
# 	Rebalancing on: 04-Aug-2014
# 	Rebalancing on: 05-Aug-2014
# 	Rebalancing on: 06-Aug-2014
# 	Rebalancing on: 07-Aug-2014
# 	Rebalancing on: 08-Aug-2014
# 	Rebalancing on: 11-Aug-2014
# 	Rebalancing on: 12-Aug-2014
# 	Rebalancing on: 13-Aug-2014
# 	Rebalancing on: 14-Aug-2014
# 	Rebalancing on: 15-Aug-2014
# 	Rebalancing on: 18-Aug-2014
# 	Rebalancing on: 19-Aug-2014
# 	Rebalancing on: 20-Aug-2014
# 	Rebalancing on: 21-Aug-2014
# 	Rebalancing on: 22-Aug-2014
# 	Rebalancing on: 25-Aug-2014
# 	Rebalancing on: 26-Aug-2014
# 	Rebalancing on: 27-Aug-2014
# 	Rebalancing on: 28-Aug-2014
# 	Rebalancing on: 29-Aug-2014
# 	Rebalancing on: 02-Sep-2014
# 	Rebalancing on: 03-Sep-2014
# 	Rebalancing on: 04-Sep-2014
# 	Rebalancing on: 05-Sep-2014
# 	Rebalancing on: 08-Sep-2014
# 	Rebalancing on: 09-Sep-2014
# 	Rebalancing on: 10-Sep-2014
# 	Rebalancing on: 11-Sep-2014
# 	Rebalancing on: 12-Sep-2014
# 	Rebalancing on: 15-Sep-2014
# 	Rebalancing on: 16-Sep-2014
# 	Rebalancing on: 17-Sep-2014
# 	Rebalancing on: 18-Sep-2014
# 	Rebalancing on: 19-Sep-2014
# 	Rebalancing on: 22-Sep-2014
# 	Rebalancing on: 23-Sep-2014
# 	Rebalancing on: 24-Sep-2014
# 	Rebalancing on: 25-Sep-2014
# 	Rebalancing on: 26-Sep-2014
# 	Rebalancing on: 29-Sep-2014
# 	Rebalancing on: 30-Sep-2014
# 	Rebalancing on: 01-Oct-2014
# 	Rebalancing on: 02-Oct-2014
# 	Rebalancing on: 03-Oct-2014
# 	Rebalancing on: 06-Oct-2014
# 	Rebalancing on: 07-Oct-2014
# 	Rebalancing on: 08-Oct-2014
# 	Rebalancing on: 09-Oct-2014
# 	Rebalancing on: 10-Oct-2014
# 	Rebalancing on: 13-Oct-2014
# 	Rebalancing on: 14-Oct-2014
# 	Rebalancing on: 15-Oct-2014
# 	Rebalancing on: 16-Oct-2014
# 	Rebalancing on: 17-Oct-2014
# 	Rebalancing on: 20-Oct-2014
# 	Rebalancing on: 21-Oct-2014
# 	Rebalancing on: 22-Oct-2014
# 	Rebalancing on: 23-Oct-2014
# 	Rebalancing on: 24-Oct-2014
# 	Rebalancing on: 27-Oct-2014
# 	Rebalancing on: 28-Oct-2014
# 	Rebalancing on: 29-Oct-2014
# 	Rebalancing on: 30-Oct-2014
# 	Rebalancing on: 31-Oct-2014
# 	Rebalancing on: 03-Nov-2014
# 	Rebalancing on: 04-Nov-2014
# 	Rebalancing on: 05-Nov-2014
# 	Rebalancing on: 06-Nov-2014
# 	Rebalancing on: 07-Nov-2014
# 	Rebalancing on: 10-Nov-2014
# 	Rebalancing on: 11-Nov-2014
# 	Rebalancing on: 12-Nov-2014
# 	Rebalancing on: 13-Nov-2014
# 	Rebalancing on: 14-Nov-2014
# 	Rebalancing on: 17-Nov-2014
# 	Rebalancing on: 18-Nov-2014
# 	Rebalancing on: 19-Nov-2014
# 	Rebalancing on: 20-Nov-2014
# 	Rebalancing on: 21-Nov-2014
# 	Rebalancing on: 24-Nov-2014
# 	Rebalancing on: 25-Nov-2014
# 	Rebalancing on: 26-Nov-2014
# 	Rebalancing on: 28-Nov-2014
# 	Rebalancing on: 01-Dec-2014
# 	Rebalancing on: 02-Dec-2014
# 	Rebalancing on: 03-Dec-2014
# 	Rebalancing on: 04-Dec-2014
# 	Rebalancing on: 05-Dec-2014
# 	Rebalancing on: 08-Dec-2014
# 	Rebalancing on: 09-Dec-2014
# 	Rebalancing on: 10-Dec-2014
# 	Rebalancing on: 11-Dec-2014
# 	Rebalancing on: 12-Dec-2014
# 	Rebalancing on: 15-Dec-2014
# 	Rebalancing on: 16-Dec-2014
# 	Rebalancing on: 17-Dec-2014
# 	Rebalancing on: 18-Dec-2014
# 	Rebalancing on: 19-Dec-2014
# 	Rebalancing on: 22-Dec-2014
# 	Rebalancing on: 23-Dec-2014
# 	Rebalancing on: 24-Dec-2014
# 	Rebalancing on: 26-Dec-2014
# 	Rebalancing on: 29-Dec-2014
# 	Rebalancing on: 30-Dec-2014
# 	Rebalancing on: 31-Dec-2014
# Reconstitution on: 02-Jan-2015
# 	Rebalancing on: 02-Jan-2015
# 	Rebalancing on: 05-Jan-2015
# 	Rebalancing on: 06-Jan-2015
# 	Rebalancing on: 07-Jan-2015
# 	Rebalancing on: 08-Jan-2015
# 	Rebalancing on: 09-Jan-2015
# 	Rebalancing on: 12-Jan-2015
# 	Rebalancing on: 13-Jan-2015
# 	Rebalancing on: 14-Jan-2015
# 	Rebalancing on: 15-Jan-2015
# 	Rebalancing on: 16-Jan-2015
# 	Rebalancing on: 20-Jan-2015
# 	Rebalancing on: 21-Jan-2015
# 	Rebalancing on: 22-Jan-2015
# 	Rebalancing on: 23-Jan-2015
# 	Rebalancing on: 26-Jan-2015
# 	Rebalancing on: 27-Jan-2015
# 	Rebalancing on: 28-Jan-2015
# 	Rebalancing on: 29-Jan-2015
# 	Rebalancing on: 30-Jan-2015
# 	Rebalancing on: 02-Feb-2015
# 	Rebalancing on: 03-Feb-2015
# 	Rebalancing on: 04-Feb-2015
# 	Rebalancing on: 05-Feb-2015
# 	Rebalancing on: 06-Feb-2015
# 	Rebalancing on: 09-Feb-2015
# 	Rebalancing on: 10-Feb-2015
# 	Rebalancing on: 11-Feb-2015
# 	Rebalancing on: 12-Feb-2015
# 	Rebalancing on: 13-Feb-2015
# 	Rebalancing on: 17-Feb-2015
# 	Rebalancing on: 18-Feb-2015
# 	Rebalancing on: 19-Feb-2015
# 	Rebalancing on: 20-Feb-2015
# 	Rebalancing on: 23-Feb-2015
# 	Rebalancing on: 24-Feb-2015
# 	Rebalancing on: 25-Feb-2015
# 	Rebalancing on: 26-Feb-2015
# 	Rebalancing on: 27-Feb-2015
# 	Rebalancing on: 02-Mar-2015
# 	Rebalancing on: 03-Mar-2015
# 	Rebalancing on: 04-Mar-2015
# 	Rebalancing on: 05-Mar-2015
# 	Rebalancing on: 06-Mar-2015
# 	Rebalancing on: 09-Mar-2015
# 	Rebalancing on: 10-Mar-2015
# 	Rebalancing on: 11-Mar-2015
# 	Rebalancing on: 12-Mar-2015
# 	Rebalancing on: 13-Mar-2015
# 	Rebalancing on: 16-Mar-2015
# 	Rebalancing on: 17-Mar-2015
# 	Rebalancing on: 18-Mar-2015
# 	Rebalancing on: 19-Mar-2015
# 	Rebalancing on: 20-Mar-2015
# 	Rebalancing on: 23-Mar-2015
# 	Rebalancing on: 24-Mar-2015
# 	Rebalancing on: 25-Mar-2015
# 	Rebalancing on: 26-Mar-2015
# 	Rebalancing on: 27-Mar-2015
# 	Rebalancing on: 30-Mar-2015
# 	Rebalancing on: 31-Mar-2015
# 	Rebalancing on: 01-Apr-2015
# 	Rebalancing on: 02-Apr-2015
# 	Rebalancing on: 06-Apr-2015
# 	Rebalancing on: 07-Apr-2015
# 	Rebalancing on: 08-Apr-2015
# 	Rebalancing on: 09-Apr-2015
# 	Rebalancing on: 10-Apr-2015
# 	Rebalancing on: 13-Apr-2015
# 	Rebalancing on: 14-Apr-2015
# 	Rebalancing on: 15-Apr-2015
# 	Rebalancing on: 16-Apr-2015
# 	Rebalancing on: 17-Apr-2015
# 	Rebalancing on: 20-Apr-2015
# 	Rebalancing on: 21-Apr-2015
# 	Rebalancing on: 22-Apr-2015
# 	Rebalancing on: 23-Apr-2015
# 	Rebalancing on: 24-Apr-2015
# 	Rebalancing on: 27-Apr-2015
# 	Rebalancing on: 28-Apr-2015
# 	Rebalancing on: 29-Apr-2015
# 	Rebalancing on: 30-Apr-2015
# 	Rebalancing on: 01-May-2015
# 	Rebalancing on: 04-May-2015
# 	Rebalancing on: 05-May-2015
# 	Rebalancing on: 06-May-2015
# 	Rebalancing on: 07-May-2015
# 	Rebalancing on: 08-May-2015
# 	Rebalancing on: 11-May-2015
# 	Rebalancing on: 12-May-2015
# 	Rebalancing on: 13-May-2015
# 	Rebalancing on: 14-May-2015
# 	Rebalancing on: 15-May-2015
# 	Rebalancing on: 18-May-2015
# 	Rebalancing on: 19-May-2015
# 	Rebalancing on: 20-May-2015
# 	Rebalancing on: 21-May-2015
# 	Rebalancing on: 22-May-2015
# 	Rebalancing on: 26-May-2015
# 	Rebalancing on: 27-May-2015
# 	Rebalancing on: 28-May-2015
# 	Rebalancing on: 29-May-2015
# 	Rebalancing on: 01-Jun-2015
# 	Rebalancing on: 02-Jun-2015
# 	Rebalancing on: 03-Jun-2015
# 	Rebalancing on: 04-Jun-2015
# 	Rebalancing on: 05-Jun-2015
# 	Rebalancing on: 08-Jun-2015
# 	Rebalancing on: 09-Jun-2015
# 	Rebalancing on: 10-Jun-2015
# 	Rebalancing on: 11-Jun-2015
# 	Rebalancing on: 12-Jun-2015
# 	Rebalancing on: 15-Jun-2015
# 	Rebalancing on: 16-Jun-2015
# 	Rebalancing on: 17-Jun-2015
# 	Rebalancing on: 18-Jun-2015
# 	Rebalancing on: 19-Jun-2015
# 	Rebalancing on: 22-Jun-2015
# 	Rebalancing on: 23-Jun-2015
# 	Rebalancing on: 24-Jun-2015
# 	Rebalancing on: 25-Jun-2015
# 	Rebalancing on: 26-Jun-2015
# 	Rebalancing on: 29-Jun-2015
# 	Rebalancing on: 30-Jun-2015
# 	Rebalancing on: 01-Jul-2015
# 	Rebalancing on: 02-Jul-2015
# 	Rebalancing on: 06-Jul-2015
# 	Rebalancing on: 07-Jul-2015
# 	Rebalancing on: 08-Jul-2015
# 	Rebalancing on: 09-Jul-2015
# 	Rebalancing on: 10-Jul-2015
# 	Rebalancing on: 13-Jul-2015
# 	Rebalancing on: 14-Jul-2015
# 	Rebalancing on: 15-Jul-2015
# 	Rebalancing on: 16-Jul-2015
# 	Rebalancing on: 17-Jul-2015
# 	Rebalancing on: 20-Jul-2015
# 	Rebalancing on: 21-Jul-2015
# 	Rebalancing on: 22-Jul-2015
# 	Rebalancing on: 23-Jul-2015
# 	Rebalancing on: 24-Jul-2015
# 	Rebalancing on: 27-Jul-2015
# 	Rebalancing on: 28-Jul-2015
# 	Rebalancing on: 29-Jul-2015
# 	Rebalancing on: 30-Jul-2015
# 	Rebalancing on: 31-Jul-2015
# 	Rebalancing on: 03-Aug-2015
# 	Rebalancing on: 04-Aug-2015
# 	Rebalancing on: 05-Aug-2015
# 	Rebalancing on: 06-Aug-2015
# 	Rebalancing on: 07-Aug-2015
# 	Rebalancing on: 10-Aug-2015
# 	Rebalancing on: 11-Aug-2015
# 	Rebalancing on: 12-Aug-2015
# 	Rebalancing on: 13-Aug-2015
# 	Rebalancing on: 14-Aug-2015
# 	Rebalancing on: 17-Aug-2015
# 	Rebalancing on: 18-Aug-2015
# 	Rebalancing on: 19-Aug-2015
# 	Rebalancing on: 20-Aug-2015
# 	Rebalancing on: 21-Aug-2015
# 	Rebalancing on: 24-Aug-2015
# 	Rebalancing on: 25-Aug-2015
# 	Rebalancing on: 26-Aug-2015
# 	Rebalancing on: 27-Aug-2015
# 	Rebalancing on: 28-Aug-2015
# 	Rebalancing on: 31-Aug-2015
# 	Rebalancing on: 01-Sep-2015
# 	Rebalancing on: 02-Sep-2015
# 	Rebalancing on: 03-Sep-2015
# 	Rebalancing on: 04-Sep-2015
# 	Rebalancing on: 08-Sep-2015
# 	Rebalancing on: 09-Sep-2015
# 	Rebalancing on: 10-Sep-2015
# 	Rebalancing on: 11-Sep-2015
# 	Rebalancing on: 14-Sep-2015
# 	Rebalancing on: 15-Sep-2015
# 	Rebalancing on: 16-Sep-2015
# 	Rebalancing on: 17-Sep-2015
# 	Rebalancing on: 18-Sep-2015
# 	Rebalancing on: 21-Sep-2015
# 	Rebalancing on: 22-Sep-2015
# 	Rebalancing on: 23-Sep-2015
# 	Rebalancing on: 24-Sep-2015
# 	Rebalancing on: 25-Sep-2015
# 	Rebalancing on: 28-Sep-2015
# 	Rebalancing on: 29-Sep-2015
# 	Rebalancing on: 30-Sep-2015
# 	Rebalancing on: 01-Oct-2015
# 	Rebalancing on: 02-Oct-2015
# 	Rebalancing on: 05-Oct-2015
# 	Rebalancing on: 06-Oct-2015
# 	Rebalancing on: 07-Oct-2015
# 	Rebalancing on: 08-Oct-2015
# 	Rebalancing on: 09-Oct-2015
# 	Rebalancing on: 12-Oct-2015
# 	Rebalancing on: 13-Oct-2015
# 	Rebalancing on: 14-Oct-2015
# 	Rebalancing on: 15-Oct-2015
# 	Rebalancing on: 16-Oct-2015
# 	Rebalancing on: 19-Oct-2015
# 	Rebalancing on: 20-Oct-2015
# 	Rebalancing on: 21-Oct-2015
# 	Rebalancing on: 22-Oct-2015
# 	Rebalancing on: 23-Oct-2015
# 	Rebalancing on: 26-Oct-2015
# 	Rebalancing on: 27-Oct-2015
# 	Rebalancing on: 28-Oct-2015
# 	Rebalancing on: 29-Oct-2015
# 	Rebalancing on: 30-Oct-2015
# 	Rebalancing on: 02-Nov-2015
# 	Rebalancing on: 03-Nov-2015
# 	Rebalancing on: 04-Nov-2015
# 	Rebalancing on: 05-Nov-2015
# 	Rebalancing on: 06-Nov-2015
# 	Rebalancing on: 09-Nov-2015
# 	Rebalancing on: 10-Nov-2015
# 	Rebalancing on: 11-Nov-2015
# 	Rebalancing on: 12-Nov-2015
# 	Rebalancing on: 13-Nov-2015
# 	Rebalancing on: 16-Nov-2015
# 	Rebalancing on: 17-Nov-2015
# 	Rebalancing on: 18-Nov-2015
# 	Rebalancing on: 19-Nov-2015
# 	Rebalancing on: 20-Nov-2015
# 	Rebalancing on: 23-Nov-2015
# 	Rebalancing on: 24-Nov-2015
# 	Rebalancing on: 25-Nov-2015
# 	Rebalancing on: 27-Nov-2015
# 	Rebalancing on: 30-Nov-2015
# 	Rebalancing on: 01-Dec-2015
# 	Rebalancing on: 02-Dec-2015
# 	Rebalancing on: 03-Dec-2015
# 	Rebalancing on: 04-Dec-2015
# 	Rebalancing on: 07-Dec-2015
# 	Rebalancing on: 08-Dec-2015
# 	Rebalancing on: 09-Dec-2015
# 	Rebalancing on: 10-Dec-2015
# 	Rebalancing on: 11-Dec-2015
# 	Rebalancing on: 14-Dec-2015
# 	Rebalancing on: 15-Dec-2015
# 	Rebalancing on: 16-Dec-2015
# 	Rebalancing on: 17-Dec-2015
# 	Rebalancing on: 18-Dec-2015
# 	Rebalancing on: 21-Dec-2015
# 	Rebalancing on: 22-Dec-2015
# 	Rebalancing on: 23-Dec-2015
# 	Rebalancing on: 24-Dec-2015
# 	Rebalancing on: 28-Dec-2015
# 	Rebalancing on: 29-Dec-2015
# 	Rebalancing on: 30-Dec-2015
# 	Rebalancing on: 31-Dec-2015
# Reconstitution on: 04-Jan-2016
# 	Rebalancing on: 04-Jan-2016
# 	Rebalancing on: 05-Jan-2016
# 	Rebalancing on: 06-Jan-2016
# 	Rebalancing on: 07-Jan-2016
# 	Rebalancing on: 08-Jan-2016
# 	Rebalancing on: 11-Jan-2016
# 	Rebalancing on: 12-Jan-2016
# 	Rebalancing on: 13-Jan-2016
# 	Rebalancing on: 14-Jan-2016
# 	Rebalancing on: 15-Jan-2016
# 	Rebalancing on: 19-Jan-2016
# 	Rebalancing on: 20-Jan-2016
# 	Rebalancing on: 21-Jan-2016
# 	Rebalancing on: 22-Jan-2016
# 	Rebalancing on: 25-Jan-2016
# 	Rebalancing on: 26-Jan-2016
# 	Rebalancing on: 27-Jan-2016
# 	Rebalancing on: 28-Jan-2016
# 	Rebalancing on: 29-Jan-2016
# 	Rebalancing on: 01-Feb-2016
# 	Rebalancing on: 02-Feb-2016
# 	Rebalancing on: 03-Feb-2016
# 	Rebalancing on: 04-Feb-2016
# 	Rebalancing on: 05-Feb-2016
# 	Rebalancing on: 08-Feb-2016
# 	Rebalancing on: 09-Feb-2016
# 	Rebalancing on: 10-Feb-2016
# 	Rebalancing on: 11-Feb-2016
# 	Rebalancing on: 12-Feb-2016
# 	Rebalancing on: 16-Feb-2016
# 	Rebalancing on: 17-Feb-2016
# 	Rebalancing on: 18-Feb-2016
# 	Rebalancing on: 19-Feb-2016
# 	Rebalancing on: 22-Feb-2016
# 	Rebalancing on: 23-Feb-2016
# 	Rebalancing on: 24-Feb-2016
# 	Rebalancing on: 25-Feb-2016
# 	Rebalancing on: 26-Feb-2016
# 	Rebalancing on: 29-Feb-2016
# 	Rebalancing on: 01-Mar-2016
# 	Rebalancing on: 02-Mar-2016
# 	Rebalancing on: 03-Mar-2016
# 	Rebalancing on: 04-Mar-2016
# 	Rebalancing on: 07-Mar-2016
# 	Rebalancing on: 08-Mar-2016
# 	Rebalancing on: 09-Mar-2016
# 	Rebalancing on: 10-Mar-2016
# 	Rebalancing on: 11-Mar-2016
# 	Rebalancing on: 14-Mar-2016
# 	Rebalancing on: 15-Mar-2016
# 	Rebalancing on: 16-Mar-2016
# 	Rebalancing on: 17-Mar-2016
# 	Rebalancing on: 18-Mar-2016
# 	Rebalancing on: 21-Mar-2016
# 	Rebalancing on: 22-Mar-2016
# 	Rebalancing on: 23-Mar-2016
# 	Rebalancing on: 24-Mar-2016
# 	Rebalancing on: 28-Mar-2016
# 	Rebalancing on: 29-Mar-2016
# 	Rebalancing on: 30-Mar-2016
# 	Rebalancing on: 31-Mar-2016
# 	Rebalancing on: 01-Apr-2016
# 	Rebalancing on: 04-Apr-2016
# 	Rebalancing on: 05-Apr-2016
# 	Rebalancing on: 06-Apr-2016
# 	Rebalancing on: 07-Apr-2016
# 	Rebalancing on: 08-Apr-2016
# 	Rebalancing on: 11-Apr-2016
# 	Rebalancing on: 12-Apr-2016
# 	Rebalancing on: 13-Apr-2016
# 	Rebalancing on: 14-Apr-2016
# 	Rebalancing on: 15-Apr-2016
# 	Rebalancing on: 18-Apr-2016
# 	Rebalancing on: 19-Apr-2016
# 	Rebalancing on: 20-Apr-2016
# 	Rebalancing on: 21-Apr-2016
# 	Rebalancing on: 22-Apr-2016
# 	Rebalancing on: 25-Apr-2016
# 	Rebalancing on: 26-Apr-2016
# 	Rebalancing on: 27-Apr-2016
# 	Rebalancing on: 28-Apr-2016
# 	Rebalancing on: 29-Apr-2016
# 	Rebalancing on: 02-May-2016
# 	Rebalancing on: 03-May-2016
# 	Rebalancing on: 04-May-2016
# 	Rebalancing on: 05-May-2016
# 	Rebalancing on: 06-May-2016
# 	Rebalancing on: 09-May-2016
# 	Rebalancing on: 10-May-2016
# 	Rebalancing on: 11-May-2016
# 	Rebalancing on: 12-May-2016
# 	Rebalancing on: 13-May-2016
# 	Rebalancing on: 16-May-2016
# 	Rebalancing on: 17-May-2016
# 	Rebalancing on: 18-May-2016
# 	Rebalancing on: 19-May-2016
# 	Rebalancing on: 20-May-2016
# 	Rebalancing on: 23-May-2016
# 	Rebalancing on: 24-May-2016
# 	Rebalancing on: 25-May-2016
# 	Rebalancing on: 26-May-2016
# 	Rebalancing on: 27-May-2016
# 	Rebalancing on: 31-May-2016
# 	Rebalancing on: 01-Jun-2016
# 	Rebalancing on: 02-Jun-2016
# 	Rebalancing on: 03-Jun-2016
# 	Rebalancing on: 06-Jun-2016
# 	Rebalancing on: 07-Jun-2016
# 	Rebalancing on: 08-Jun-2016
# 	Rebalancing on: 09-Jun-2016
# 	Rebalancing on: 10-Jun-2016
# 	Rebalancing on: 13-Jun-2016
# 	Rebalancing on: 14-Jun-2016
# 	Rebalancing on: 15-Jun-2016
# 	Rebalancing on: 16-Jun-2016
# 	Rebalancing on: 17-Jun-2016
# 	Rebalancing on: 20-Jun-2016
# 	Rebalancing on: 21-Jun-2016
# 	Rebalancing on: 22-Jun-2016
# 	Rebalancing on: 23-Jun-2016
# 	Rebalancing on: 24-Jun-2016
# 	Rebalancing on: 27-Jun-2016
# 	Rebalancing on: 28-Jun-2016
# 	Rebalancing on: 29-Jun-2016
# 	Rebalancing on: 30-Jun-2016
# 	Rebalancing on: 01-Jul-2016
# 	Rebalancing on: 05-Jul-2016
# 	Rebalancing on: 06-Jul-2016
# 	Rebalancing on: 07-Jul-2016
# 	Rebalancing on: 08-Jul-2016
# 	Rebalancing on: 11-Jul-2016
# 	Rebalancing on: 12-Jul-2016
# 	Rebalancing on: 13-Jul-2016
# 	Rebalancing on: 14-Jul-2016
# 	Rebalancing on: 15-Jul-2016
# 	Rebalancing on: 18-Jul-2016
# 	Rebalancing on: 19-Jul-2016
# ...
# 	Rebalancing on: 21-Nov-2018
# 	Rebalancing on: 23-Nov-2018
# 	Rebalancing on: 26-Nov-2018
# 	Rebalancing on: 27-Nov-2018
# 	Rebalancing on: 28-Nov-2018
# 	Rebalancing on: 29-Nov-2018
# 	Rebalancing on: 30-Nov-2018
# 	Rebalancing on: 03-Dec-2018
# 	Rebalancing on: 04-Dec-2018
# 	Rebalancing on: 06-Dec-2018
# 	Rebalancing on: 07-Dec-2018
# 	Rebalancing on: 10-Dec-2018
# 	Rebalancing on: 11-Dec-2018
# 	Rebalancing on: 12-Dec-2018
# 	Rebalancing on: 13-Dec-2018
# 	Rebalancing on: 14-Dec-2018
# 	Rebalancing on: 17-Dec-2018
# 	Rebalancing on: 18-Dec-2018
# 	Rebalancing on: 19-Dec-2018
# 	Rebalancing on: 20-Dec-2018
# 	Rebalancing on: 21-Dec-2018
# 	Rebalancing on: 24-Dec-2018
# 	Rebalancing on: 26-Dec-2018
# 	Rebalancing on: 27-Dec-2018
# 	Rebalancing on: 28-Dec-2018
# 	Rebalancing on: 31-Dec-2018
# Reconstitution on: 02-Jan-2019
# 	Rebalancing on: 02-Jan-2019
# 	Rebalancing on: 03-Jan-2019
# 	Rebalancing on: 04-Jan-2019
# 	Rebalancing on: 07-Jan-2019
# 	Rebalancing on: 08-Jan-2019
# 	Rebalancing on: 09-Jan-2019
# 	Rebalancing on: 10-Jan-2019
# 	Rebalancing on: 11-Jan-2019
# 	Rebalancing on: 14-Jan-2019
# 	Rebalancing on: 15-Jan-2019
# 	Rebalancing on: 16-Jan-2019
# 	Rebalancing on: 17-Jan-2019
# 	Rebalancing on: 18-Jan-2019
# 	Rebalancing on: 22-Jan-2019
# 	Rebalancing on: 23-Jan-2019
# 	Rebalancing on: 24-Jan-2019
# 	Rebalancing on: 25-Jan-2019
# 	Rebalancing on: 28-Jan-2019
# 	Rebalancing on: 29-Jan-2019
# 	Rebalancing on: 30-Jan-2019
# 	Rebalancing on: 31-Jan-2019
# 	Rebalancing on: 01-Feb-2019
# 	Rebalancing on: 04-Feb-2019
# 	Rebalancing on: 05-Feb-2019
# 	Rebalancing on: 06-Feb-2019
# 	Rebalancing on: 07-Feb-2019
# 	Rebalancing on: 08-Feb-2019
# 	Rebalancing on: 11-Feb-2019
# 	Rebalancing on: 12-Feb-2019
# 	Rebalancing on: 13-Feb-2019
# 	Rebalancing on: 14-Feb-2019
# 	Rebalancing on: 15-Feb-2019
# 	Rebalancing on: 19-Feb-2019
# 	Rebalancing on: 20-Feb-2019
# 	Rebalancing on: 21-Feb-2019
# 	Rebalancing on: 22-Feb-2019
# 	Rebalancing on: 25-Feb-2019
# 	Rebalancing on: 26-Feb-2019
# 	Rebalancing on: 27-Feb-2019
# 	Rebalancing on: 28-Feb-2019
# 	Rebalancing on: 01-Mar-2019
# 	Rebalancing on: 04-Mar-2019
# 	Rebalancing on: 05-Mar-2019
# 	Rebalancing on: 06-Mar-2019
# 	Rebalancing on: 07-Mar-2019
# 	Rebalancing on: 08-Mar-2019
# 	Rebalancing on: 11-Mar-2019
# 	Rebalancing on: 12-Mar-2019
# 	Rebalancing on: 13-Mar-2019
# 	Rebalancing on: 14-Mar-2019
# 	Rebalancing on: 15-Mar-2019
# 	Rebalancing on: 18-Mar-2019
# 	Rebalancing on: 19-Mar-2019
# 	Rebalancing on: 20-Mar-2019
# 	Rebalancing on: 21-Mar-2019
# 	Rebalancing on: 22-Mar-2019
# 	Rebalancing on: 25-Mar-2019
# 	Rebalancing on: 26-Mar-2019
# 	Rebalancing on: 27-Mar-2019
# 	Rebalancing on: 28-Mar-2019
# 	Rebalancing on: 29-Mar-2019
# 	Rebalancing on: 01-Apr-2019
# 	Rebalancing on: 02-Apr-2019
# 	Rebalancing on: 03-Apr-2019
# 	Rebalancing on: 04-Apr-2019
# 	Rebalancing on: 05-Apr-2019
# 	Rebalancing on: 08-Apr-2019
# 	Rebalancing on: 09-Apr-2019
# 	Rebalancing on: 10-Apr-2019
# 	Rebalancing on: 11-Apr-2019
# 	Rebalancing on: 12-Apr-2019
# 	Rebalancing on: 15-Apr-2019
# 	Rebalancing on: 16-Apr-2019
# 	Rebalancing on: 17-Apr-2019
# 	Rebalancing on: 18-Apr-2019
# 	Rebalancing on: 22-Apr-2019
# 	Rebalancing on: 23-Apr-2019
# 	Rebalancing on: 24-Apr-2019
# 	Rebalancing on: 25-Apr-2019
# 	Rebalancing on: 26-Apr-2019
# 	Rebalancing on: 29-Apr-2019
# 	Rebalancing on: 30-Apr-2019
# 	Rebalancing on: 01-May-2019
# 	Rebalancing on: 02-May-2019
# 	Rebalancing on: 03-May-2019
# 	Rebalancing on: 06-May-2019
# 	Rebalancing on: 07-May-2019
# 	Rebalancing on: 08-May-2019
# 	Rebalancing on: 09-May-2019
# 	Rebalancing on: 10-May-2019
# 	Rebalancing on: 13-May-2019
# 	Rebalancing on: 14-May-2019
# 	Rebalancing on: 15-May-2019
# 	Rebalancing on: 16-May-2019
# 	Rebalancing on: 17-May-2019
# 	Rebalancing on: 20-May-2019
# 	Rebalancing on: 21-May-2019
# 	Rebalancing on: 22-May-2019
# 	Rebalancing on: 23-May-2019
# 	Rebalancing on: 24-May-2019
# 	Rebalancing on: 28-May-2019
# 	Rebalancing on: 29-May-2019
# 	Rebalancing on: 30-May-2019
# 	Rebalancing on: 31-May-2019
# 	Rebalancing on: 03-Jun-2019
# 	Rebalancing on: 04-Jun-2019
# 	Rebalancing on: 05-Jun-2019
# 	Rebalancing on: 06-Jun-2019
# 	Rebalancing on: 07-Jun-2019
# 	Rebalancing on: 10-Jun-2019
# 	Rebalancing on: 11-Jun-2019
# 	Rebalancing on: 12-Jun-2019
# 	Rebalancing on: 13-Jun-2019
# 	Rebalancing on: 14-Jun-2019
# 	Rebalancing on: 17-Jun-2019
# 	Rebalancing on: 18-Jun-2019
# 	Rebalancing on: 19-Jun-2019
# 	Rebalancing on: 20-Jun-2019
# 	Rebalancing on: 21-Jun-2019
# 	Rebalancing on: 24-Jun-2019
# 	Rebalancing on: 25-Jun-2019
# 	Rebalancing on: 26-Jun-2019
# 	Rebalancing on: 27-Jun-2019
# 	Rebalancing on: 28-Jun-2019
# 	Rebalancing on: 01-Jul-2019
# 	Rebalancing on: 02-Jul-2019
# 	Rebalancing on: 03-Jul-2019
# 	Rebalancing on: 05-Jul-2019
# 	Rebalancing on: 08-Jul-2019
# 	Rebalancing on: 09-Jul-2019
# 	Rebalancing on: 10-Jul-2019
# 	Rebalancing on: 11-Jul-2019
# 	Rebalancing on: 12-Jul-2019
# 	Rebalancing on: 15-Jul-2019
# 	Rebalancing on: 16-Jul-2019
# 	Rebalancing on: 17-Jul-2019
# 	Rebalancing on: 18-Jul-2019
# 	Rebalancing on: 19-Jul-2019
# 	Rebalancing on: 22-Jul-2019
# 	Rebalancing on: 23-Jul-2019
# 	Rebalancing on: 24-Jul-2019
# 	Rebalancing on: 25-Jul-2019
# 	Rebalancing on: 26-Jul-2019
# 	Rebalancing on: 29-Jul-2019
# 	Rebalancing on: 30-Jul-2019
# 	Rebalancing on: 31-Jul-2019
# 	Rebalancing on: 01-Aug-2019
# 	Rebalancing on: 02-Aug-2019
# 	Rebalancing on: 05-Aug-2019
# 	Rebalancing on: 06-Aug-2019
# 	Rebalancing on: 07-Aug-2019
# 	Rebalancing on: 08-Aug-2019
# 	Rebalancing on: 09-Aug-2019
# 	Rebalancing on: 12-Aug-2019
# 	Rebalancing on: 13-Aug-2019
# 	Rebalancing on: 14-Aug-2019
# 	Rebalancing on: 15-Aug-2019
# 	Rebalancing on: 16-Aug-2019
# 	Rebalancing on: 19-Aug-2019
# 	Rebalancing on: 20-Aug-2019
# 	Rebalancing on: 21-Aug-2019
# 	Rebalancing on: 22-Aug-2019
# 	Rebalancing on: 23-Aug-2019
# 	Rebalancing on: 26-Aug-2019
# 	Rebalancing on: 27-Aug-2019
# 	Rebalancing on: 28-Aug-2019
# 	Rebalancing on: 29-Aug-2019
# 	Rebalancing on: 30-Aug-2019
# 	Rebalancing on: 03-Sep-2019
# 	Rebalancing on: 04-Sep-2019
# 	Rebalancing on: 05-Sep-2019
# 	Rebalancing on: 06-Sep-2019
# 	Rebalancing on: 09-Sep-2019
# 	Rebalancing on: 10-Sep-2019
# 	Rebalancing on: 11-Sep-2019
# 	Rebalancing on: 12-Sep-2019
# 	Rebalancing on: 13-Sep-2019
# 	Rebalancing on: 16-Sep-2019
# 	Rebalancing on: 17-Sep-2019
# 	Rebalancing on: 18-Sep-2019
# 	Rebalancing on: 19-Sep-2019
# 	Rebalancing on: 20-Sep-2019
# 	Rebalancing on: 23-Sep-2019
# 	Rebalancing on: 24-Sep-2019
# 	Rebalancing on: 25-Sep-2019
# 	Rebalancing on: 26-Sep-2019
# 	Rebalancing on: 27-Sep-2019
# 	Rebalancing on: 30-Sep-2019
# 	Rebalancing on: 01-Oct-2019
# 	Rebalancing on: 02-Oct-2019
# 	Rebalancing on: 03-Oct-2019
# 	Rebalancing on: 04-Oct-2019
# 	Rebalancing on: 07-Oct-2019
# 	Rebalancing on: 08-Oct-2019
# 	Rebalancing on: 09-Oct-2019
# 	Rebalancing on: 10-Oct-2019
# 	Rebalancing on: 11-Oct-2019
# 	Rebalancing on: 14-Oct-2019
# 	Rebalancing on: 15-Oct-2019
# 	Rebalancing on: 16-Oct-2019
# 	Rebalancing on: 17-Oct-2019
# 	Rebalancing on: 18-Oct-2019
# 	Rebalancing on: 21-Oct-2019
# 	Rebalancing on: 22-Oct-2019
# 	Rebalancing on: 23-Oct-2019
# 	Rebalancing on: 24-Oct-2019
# 	Rebalancing on: 25-Oct-2019
# 	Rebalancing on: 28-Oct-2019
# 	Rebalancing on: 29-Oct-2019
# 	Rebalancing on: 30-Oct-2019
# 	Rebalancing on: 31-Oct-2019
# 	Rebalancing on: 01-Nov-2019
# 	Rebalancing on: 04-Nov-2019
# 	Rebalancing on: 05-Nov-2019
# 	Rebalancing on: 06-Nov-2019
# 	Rebalancing on: 07-Nov-2019
# 	Rebalancing on: 08-Nov-2019
# 	Rebalancing on: 11-Nov-2019
# 	Rebalancing on: 12-Nov-2019
# 	Rebalancing on: 13-Nov-2019
# 	Rebalancing on: 14-Nov-2019
# 	Rebalancing on: 15-Nov-2019
# 	Rebalancing on: 18-Nov-2019
# 	Rebalancing on: 19-Nov-2019
# 	Rebalancing on: 20-Nov-2019
# 	Rebalancing on: 21-Nov-2019
# 	Rebalancing on: 22-Nov-2019
# 	Rebalancing on: 25-Nov-2019
# 	Rebalancing on: 26-Nov-2019
# 	Rebalancing on: 27-Nov-2019
# 	Rebalancing on: 29-Nov-2019
# 	Rebalancing on: 02-Dec-2019
# 	Rebalancing on: 03-Dec-2019
# 	Rebalancing on: 04-Dec-2019
# 	Rebalancing on: 05-Dec-2019
# 	Rebalancing on: 06-Dec-2019
# 	Rebalancing on: 09-Dec-2019
# 	Rebalancing on: 10-Dec-2019
# 	Rebalancing on: 11-Dec-2019
# 	Rebalancing on: 12-Dec-2019
# 	Rebalancing on: 13-Dec-2019
# 	Rebalancing on: 16-Dec-2019
# 	Rebalancing on: 17-Dec-2019
# 	Rebalancing on: 18-Dec-2019
# 	Rebalancing on: 19-Dec-2019
# 	Rebalancing on: 20-Dec-2019
# 	Rebalancing on: 23-Dec-2019
# 	Rebalancing on: 24-Dec-2019
# 	Rebalancing on: 26-Dec-2019
# 	Rebalancing on: 27-Dec-2019
# 	Rebalancing on: 30-Dec-2019
# 	Rebalancing on: 31-Dec-2019
# Reconstitution on: 02-Jan-2020
# 	Rebalancing on: 02-Jan-2020
# 	Rebalancing on: 03-Jan-2020
# 	Rebalancing on: 06-Jan-2020
# 	Rebalancing on: 07-Jan-2020
# 	Rebalancing on: 08-Jan-2020
# 	Rebalancing on: 09-Jan-2020
# 	Rebalancing on: 10-Jan-2020
# 	Rebalancing on: 13-Jan-2020
# 	Rebalancing on: 14-Jan-2020
# 	Rebalancing on: 15-Jan-2020
# 	Rebalancing on: 16-Jan-2020
# 	Rebalancing on: 17-Jan-2020
# 	Rebalancing on: 21-Jan-2020
# 	Rebalancing on: 22-Jan-2020
# 	Rebalancing on: 23-Jan-2020
# 	Rebalancing on: 24-Jan-2020
# 	Rebalancing on: 27-Jan-2020
# 	Rebalancing on: 28-Jan-2020
# 	Rebalancing on: 29-Jan-2020
# 	Rebalancing on: 30-Jan-2020
# 	Rebalancing on: 31-Jan-2020
# 	Rebalancing on: 03-Feb-2020
# 	Rebalancing on: 04-Feb-2020
# 	Rebalancing on: 05-Feb-2020
# 	Rebalancing on: 06-Feb-2020
# 	Rebalancing on: 07-Feb-2020
# 	Rebalancing on: 10-Feb-2020
# 	Rebalancing on: 11-Feb-2020
# 	Rebalancing on: 12-Feb-2020
# 	Rebalancing on: 13-Feb-2020
# 	Rebalancing on: 14-Feb-2020
# 	Rebalancing on: 18-Feb-2020
# 	Rebalancing on: 19-Feb-2020
# 	Rebalancing on: 20-Feb-2020
# 	Rebalancing on: 21-Feb-2020
# 	Rebalancing on: 24-Feb-2020
# 	Rebalancing on: 25-Feb-2020
# 	Rebalancing on: 26-Feb-2020
# 	Rebalancing on: 27-Feb-2020
# 	Rebalancing on: 28-Feb-2020
# 	Rebalancing on: 02-Mar-2020
# 	Rebalancing on: 03-Mar-2020
# 	Rebalancing on: 04-Mar-2020
# 	Rebalancing on: 05-Mar-2020
# 	Rebalancing on: 06-Mar-2020
# 	Rebalancing on: 09-Mar-2020
# 	Rebalancing on: 10-Mar-2020
# 	Rebalancing on: 11-Mar-2020
# 	Rebalancing on: 12-Mar-2020
# 	Rebalancing on: 13-Mar-2020
# 	Rebalancing on: 16-Mar-2020
# 	Rebalancing on: 17-Mar-2020
# 	Rebalancing on: 18-Mar-2020
# 	Rebalancing on: 19-Mar-2020
# 	Rebalancing on: 20-Mar-2020
# 	Rebalancing on: 23-Mar-2020
# 	Rebalancing on: 24-Mar-2020
# 	Rebalancing on: 25-Mar-2020
# 	Rebalancing on: 26-Mar-2020
# 	Rebalancing on: 27-Mar-2020
# 	Rebalancing on: 30-Mar-2020
# 	Rebalancing on: 31-Mar-2020
# 	Rebalancing on: 01-Apr-2020
# 	Rebalancing on: 02-Apr-2020
# 	Rebalancing on: 03-Apr-2020
# 	Rebalancing on: 06-Apr-2020
# 	Rebalancing on: 07-Apr-2020
# 	Rebalancing on: 08-Apr-2020
# 	Rebalancing on: 09-Apr-2020
# 	Rebalancing on: 13-Apr-2020
# 	Rebalancing on: 14-Apr-2020
# 	Rebalancing on: 15-Apr-2020
# 	Rebalancing on: 16-Apr-2020
# 	Rebalancing on: 17-Apr-2020
# 	Rebalancing on: 20-Apr-2020
# 	Rebalancing on: 21-Apr-2020
# 	Rebalancing on: 22-Apr-2020
# 	Rebalancing on: 23-Apr-2020
# 	Rebalancing on: 24-Apr-2020
# 	Rebalancing on: 27-Apr-2020
# 	Rebalancing on: 28-Apr-2020
# 	Rebalancing on: 29-Apr-2020
# 	Rebalancing on: 30-Apr-2020
# 	Rebalancing on: 01-May-2020
# 	Rebalancing on: 04-May-2020
# 	Rebalancing on: 05-May-2020
# 	Rebalancing on: 06-May-2020
# 	Rebalancing on: 07-May-2020
# 	Rebalancing on: 08-May-2020
# 	Rebalancing on: 11-May-2020
# 	Rebalancing on: 12-May-2020
# 	Rebalancing on: 13-May-2020
# 	Rebalancing on: 14-May-2020
# 	Rebalancing on: 15-May-2020
# 	Rebalancing on: 18-May-2020
# 	Rebalancing on: 19-May-2020
# 	Rebalancing on: 20-May-2020
# 	Rebalancing on: 21-May-2020
# 	Rebalancing on: 22-May-2020
# 	Rebalancing on: 26-May-2020
# 	Rebalancing on: 27-May-2020
# 	Rebalancing on: 28-May-2020
# 	Rebalancing on: 29-May-2020
# 	Rebalancing on: 01-Jun-2020
# 	Rebalancing on: 02-Jun-2020
# 	Rebalancing on: 03-Jun-2020
# 	Rebalancing on: 04-Jun-2020
# 	Rebalancing on: 05-Jun-2020
# 	Rebalancing on: 08-Jun-2020
# 	Rebalancing on: 09-Jun-2020
# 	Rebalancing on: 10-Jun-2020
# 	Rebalancing on: 11-Jun-2020
# 	Rebalancing on: 12-Jun-2020
# 	Rebalancing on: 15-Jun-2020
# 	Rebalancing on: 16-Jun-2020
# 	Rebalancing on: 17-Jun-2020
# 	Rebalancing on: 18-Jun-2020
# 	Rebalancing on: 19-Jun-2020
# 	Rebalancing on: 22-Jun-2020
# 	Rebalancing on: 23-Jun-2020
# 	Rebalancing on: 24-Jun-2020
# 	Rebalancing on: 25-Jun-2020
# 	Rebalancing on: 26-Jun-2020
# 	Rebalancing on: 29-Jun-2020
# 	Rebalancing on: 30-Jun-2020
# 	Rebalancing on: 01-Jul-2020
# 	Rebalancing on: 02-Jul-2020
# 	Rebalancing on: 06-Jul-2020
# 	Rebalancing on: 07-Jul-2020
# 	Rebalancing on: 08-Jul-2020
# 	Rebalancing on: 09-Jul-2020
# 	Rebalancing on: 10-Jul-2020
# 	Rebalancing on: 13-Jul-2020
# 	Rebalancing on: 14-Jul-2020
# 	Rebalancing on: 15-Jul-2020
# 	Rebalancing on: 16-Jul-2020
# 	Rebalancing on: 17-Jul-2020
# 	Rebalancing on: 20-Jul-2020
# 	Rebalancing on: 21-Jul-2020
# 	Rebalancing on: 22-Jul-2020
# 	Rebalancing on: 23-Jul-2020
# 	Rebalancing on: 24-Jul-2020
# 	Rebalancing on: 27-Jul-2020
# 	Rebalancing on: 28-Jul-2020
# 	Rebalancing on: 29-Jul-2020
# 	Rebalancing on: 30-Jul-2020
# 	Rebalancing on: 31-Jul-2020
# 	Rebalancing on: 03-Aug-2020
# 	Rebalancing on: 04-Aug-2020
# 	Rebalancing on: 05-Aug-2020
# 	Rebalancing on: 06-Aug-2020
# 	Rebalancing on: 07-Aug-2020
# 	Rebalancing on: 10-Aug-2020
# 	Rebalancing on: 11-Aug-2020
# 	Rebalancing on: 12-Aug-2020
# 	Rebalancing on: 13-Aug-2020
# 	Rebalancing on: 14-Aug-2020
# 	Rebalancing on: 17-Aug-2020
# 	Rebalancing on: 18-Aug-2020
# 	Rebalancing on: 19-Aug-2020
# 	Rebalancing on: 20-Aug-2020
# 	Rebalancing on: 21-Aug-2020
# 	Rebalancing on: 24-Aug-2020
# 	Rebalancing on: 25-Aug-2020
# 	Rebalancing on: 26-Aug-2020
# 	Rebalancing on: 27-Aug-2020
# 	Rebalancing on: 28-Aug-2020
# 	Rebalancing on: 31-Aug-2020
# 	Rebalancing on: 01-Sep-2020
# 	Rebalancing on: 02-Sep-2020
# 	Rebalancing on: 03-Sep-2020
# 	Rebalancing on: 04-Sep-2020
# 	Rebalancing on: 08-Sep-2020
# 	Rebalancing on: 09-Sep-2020
# 	Rebalancing on: 10-Sep-2020
# 	Rebalancing on: 11-Sep-2020
# 	Rebalancing on: 14-Sep-2020
# 	Rebalancing on: 15-Sep-2020
# 	Rebalancing on: 16-Sep-2020
# 	Rebalancing on: 17-Sep-2020
# 	Rebalancing on: 18-Sep-2020
# 	Rebalancing on: 21-Sep-2020
# 	Rebalancing on: 22-Sep-2020
# 	Rebalancing on: 23-Sep-2020
# 	Rebalancing on: 24-Sep-2020
# 	Rebalancing on: 25-Sep-2020
# 	Rebalancing on: 28-Sep-2020
# 	Rebalancing on: 29-Sep-2020
# 	Rebalancing on: 30-Sep-2020
# 	Rebalancing on: 01-Oct-2020
# 	Rebalancing on: 02-Oct-2020
# 	Rebalancing on: 05-Oct-2020
# 	Rebalancing on: 06-Oct-2020
# 	Rebalancing on: 07-Oct-2020
# 	Rebalancing on: 08-Oct-2020
# 	Rebalancing on: 09-Oct-2020
# 	Rebalancing on: 12-Oct-2020
# 	Rebalancing on: 13-Oct-2020
# 	Rebalancing on: 14-Oct-2020
# 	Rebalancing on: 15-Oct-2020
# 	Rebalancing on: 16-Oct-2020
# 	Rebalancing on: 19-Oct-2020
# 	Rebalancing on: 20-Oct-2020
# 	Rebalancing on: 21-Oct-2020
# 	Rebalancing on: 22-Oct-2020
# 	Rebalancing on: 23-Oct-2020
# 	Rebalancing on: 26-Oct-2020
# 	Rebalancing on: 27-Oct-2020
# 	Rebalancing on: 28-Oct-2020
# 	Rebalancing on: 29-Oct-2020
# 	Rebalancing on: 30-Oct-2020
# 	Rebalancing on: 02-Nov-2020
# 	Rebalancing on: 03-Nov-2020
# 	Rebalancing on: 04-Nov-2020
# 	Rebalancing on: 05-Nov-2020
# 	Rebalancing on: 06-Nov-2020
# 	Rebalancing on: 09-Nov-2020
# 	Rebalancing on: 10-Nov-2020
# 	Rebalancing on: 11-Nov-2020
# 	Rebalancing on: 12-Nov-2020
# 	Rebalancing on: 13-Nov-2020
# 	Rebalancing on: 16-Nov-2020
# 	Rebalancing on: 17-Nov-2020
# 	Rebalancing on: 18-Nov-2020
# 	Rebalancing on: 19-Nov-2020
# 	Rebalancing on: 20-Nov-2020
# 	Rebalancing on: 23-Nov-2020
# 	Rebalancing on: 24-Nov-2020
# 	Rebalancing on: 25-Nov-2020
# 	Rebalancing on: 27-Nov-2020
# 	Rebalancing on: 30-Nov-2020
# 	Rebalancing on: 01-Dec-2020
# 	Rebalancing on: 02-Dec-2020
# 	Rebalancing on: 03-Dec-2020
# 	Rebalancing on: 04-Dec-2020
# 	Rebalancing on: 07-Dec-2020
# 	Rebalancing on: 08-Dec-2020
# 	Rebalancing on: 09-Dec-2020
# 	Rebalancing on: 10-Dec-2020
# 	Rebalancing on: 11-Dec-2020
# 	Rebalancing on: 14-Dec-2020
# 	Rebalancing on: 15-Dec-2020
# 	Rebalancing on: 16-Dec-2020
# 	Rebalancing on: 17-Dec-2020
# 	Rebalancing on: 18-Dec-2020
# 	Rebalancing on: 21-Dec-2020
# 	Rebalancing on: 22-Dec-2020
# 	Rebalancing on: 23-Dec-2020
# 	Rebalancing on: 24-Dec-2020
# 	Rebalancing on: 28-Dec-2020
# 	Rebalancing on: 29-Dec-2020
# 	Rebalancing on: 30-Dec-2020
# 	Rebalancing on: 31-Dec-2020
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Code/GitHub/Finance/InvestmentStategies - Vito/index-mimiking-portfolio/portfolio.py in <module>
#       5     tmpdf = djia_data.loc[date,:]
#       6
# ----> 7     valuation, returns =  djia_portfolio.run(date= date, price= tmpdf, tickerlist = djia_ticker[date.year])
#       8     portfolio_val[date] = valuation
#       9     portfolio_returns[date] = returns
#
# KeyError: 2021

# %%
djia_portfolio.echo()
# print("Net return since start: ",djia_portfolio.net_return()*100,"%")
# Out:
# Target Index: DJIA
# Trading Algorithm: Dow Jones Algo
# Starting Investment: 1000000
# Current Investment: 2618085.6255883463
# Constituent Indices: MMM, GS, NKE, AXP, HD ...
# Constituent Weights: tic
# HON    562.812514
# PG     562.812514
# DIS    562.812514
# BA     562.812514
# VZ     562.812514
# dtype: float64

# %%
from scipy.stats.mstats import gmean
print("daily return: ",(gmean(portfolio_returns+1)-1)*100,"%")
# Out:
# daily return:  0.033079633043442414 %

# %% [markdown]
# ## DJIA Index, ETF and Mutual Fund(Not yet available)

# %%
benchmark_data = yf.download("^DJI DIA VTSMX", start="2010-01-01", end="2021-10-07")
benchmark_data = benchmark_data["Close"]#.loc[portfolio_returns.index]
benchmark_data.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#                    DIA      VTSMX          ^DJI
# Date
# 2010-01-04  105.660004  27.910000  10583.959961
# 2010-01-05  105.489998  27.990000  10572.019531
# 2010-01-06  105.559998  28.030001  10573.679688
# 2010-01-07  105.940002  28.150000  10606.860352
# 2010-01-08  106.110001  28.240000  10618.190430

# %%
baseline_return = benchmark_data.apply(daily_returns).fillna(0)
baseline_return.head()
# Out:
#                  DIA     VTSMX      ^DJI
# Date
# 2010-01-04  0.000000  0.000000  0.000000
# 2010-01-05 -0.001609  0.002866 -0.001128
# 2010-01-06  0.000664  0.001429  0.000157
# 2010-01-07  0.003600  0.004281  0.003138
# 2010-01-08  0.001605  0.003197  0.001068

# %% [markdown]
# ## Plot

# %%
fig, ax = plt.subplots(1,2, sharex= False, sharey=False)
fig.set_size_inches(30, 10,  forward=True)

ax[0].plot(portfolio_val)
ax[0].plot((benchmark_data["^DJI"]-584)*100)
ax[0].plot((benchmark_data["DIA"]-5.66)*10000)
ax[0].plot(benchmark_data["VTSMX"]*30000 + 162700)
ax[0].legend(["Portfolio Value","^DJI","DIA","VTSMX"])
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Portfolio Net Asset Value (in million $)")
ax[0].set_title("Portfolio v/s benchmarks - Valuation")

ax[1].plot(portfolio_returns)
ax[1].plot(baseline_return["^DJI"])
ax[1].plot(baseline_return["DIA"])
ax[1].plot(baseline_return["VTSMX"])
ax[1].legend(["Portfolio Returns","^DJI","DIA","VTSMX"])
ax[1].set_xlabel("Time")
ax[1].set_ylabel("Portfolio Daily Returns")
ax[1].set_title("Portfolio v/s benchmarks - Returns")

fig.suptitle('DJIA Replicating Portfolio',fontsize=20);

# %%
tracking_error_djia = baseline_return.apply(lambda x: (tracking_error(portfolio_returns,x)))
for index, value in tracking_error_djia.iteritems():
    print("Tracking error between our portfolio and {target} is {std}%".format(target = index, std = str(round(value,5)*100)))
# Out:
# Tracking error between our portfolio and DIA is 0.25%
# Tracking error between our portfolio and VTSMX is 0.46499999999999997%
# Tracking error between our portfolio and ^DJI is 0.23900000000000002%

# %%
plt.figure().set_size_inches(30, 10,  forward=True)

plt.plot(portfolio_val)
plt.plot((benchmark_data["^DJI"]-584)*100)
plt.plot((benchmark_data["DIA"]-5.66)*10000)
plt.plot(benchmark_data["VTSMX"]*30000 + 162700)
plt.legend(["Portfolio Value","^DJI","DIA","VTSMX"])
plt.xlabel("Time")
plt.ylabel("Portfolio Net Asset Value (in million $)")
plt.title("DJIA Portfolio v/s benchmarks - Valuation")
plt.show()

# %% [markdown]
# ***
# ***
